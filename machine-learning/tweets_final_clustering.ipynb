# %% [markdown]
# # Tweet Clusters

# %% [markdown]
# ### Environment Prep

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

import re
import glob
import json

import time

import nltk

from sklearn.externals import joblib

# %% [markdown]
# Read all json files, append to a list, and concat into a dataframe called "tweets"

# %%
read_files = glob.glob("data/*.json")
print(read_files)
print() ; 

files = []
for file in read_files:
    files.append(pd.read_json(file))
    print('Appending ' + file + '...')

print() ; 
tweets = pd.concat(files)
print(tweets.shape)
# Out:
# ['data/mar01_apr01.json', 'data/nov01_dec01.json', 'data/jan01_feb01.json', 'data/feb01_mar01.json', 'data/apr01_apr14.json', 'data/dec01_jan01.json', 'data/oct20_nov01.json', 'data/oct14_oct20.json']
#
# Appending data/mar01_apr01.json...
# Appending data/nov01_dec01.json...
# Appending data/jan01_feb01.json...
# Appending data/feb01_mar01.json...
# Appending data/apr01_apr14.json...
# Appending data/dec01_jan01.json...
# Appending data/oct20_nov01.json...
# Appending data/oct14_oct20.json...
#
# (1392076, 10)

# %%
# print(tweets.head(3))

# %%
data = tweets

# %% [markdown]
# ### Clean the data

# %%
data['original_text'] = data['text']

# %%
# 'http' matches literal characters
# '\S+' matches all non-whitespace characters (the end of the url)

# remove http links
data['text'] = data['text'].str.replace('http\S+', '', case=False)

# remove www links
data['text'] = data['text'].str.replace('www.\S+', '', case=False)

# remove twitter pics
data['text'] = data['text'].str.replace('pic.twitter.com\S+', '', case=False)

# %%
# create a function to search for hashtags
def hashtagSearch(text):
    array = []
    for word in text.split(' '):
        if len(word) > 1:
            if word[0] =='#':
                array.append(word)
    return(array)

# make new column of hashtags
data['hashtags'] = data['text'].apply(hashtagSearch)
# print(data.head)

# %%
# create a function to search for usernames
def usernameSearch(text):
    array = []
    for word in text.split(' '):
        if len(word) > 1:
            if word[0] =='@':
                array.append(word)
    return(array)

# make new column of hashtags
data['usernames'] = data['text'].apply(usernameSearch)
# print(data.head)

# %%
# remove hashtags
data['text'] = data['text'].str.replace('#\S+', '', case=False)

# remove users
data['text'] = data['text'].str.replace('@\S+', '', case=False)

# remove …
data['text'] = data['text'].str.replace('…','')

# %%
tweets['engagement'] = tweets['likes'] + tweets['replies'] + 2*tweets['retweets']

# %%
print(data.head())
joblib.dump(data, 'data.pkl')
# Out:
#         fullname                                               html  \
# 0    Judy Gayton  <p class="TweetTextSize js-tweet-text tweet-te...
# 1          julie  <p class="TweetTextSize js-tweet-text tweet-te...
# 2  Rachel Powell  <p class="TweetTextSize js-tweet-text tweet-te...
# 3  Kevin Johnson  <p class="TweetTextSize js-tweet-text tweet-te...
# 4   JohnnyZipper  <p class="TweetTextSize js-tweet-text tweet-te...
#
#                    id  likes  replies  retweets  \
# 0  980233135471214592      6        1        10
# 1  980233120401240064      0        0         0
# 2  980233027103072256      0        0         0
# 3  980232921100570624      0        0         0
# 4  980232826523193344      1        0         0
#
#                                                 text           timestamp  \
# 0  Despite 45% being sexually assaulted/raped (22... 2018-03-31 23:59:26
# 1                     How Easter became a  moment\n  2018-03-31 23:59:22
# 2          Praying and grateful for your strength!   2018-03-31 23:59:00
# 3   not to diminish  but to say Me too about anot... 2018-03-31 23:58:34
# 4  CNN Article Claims That The Easter Story Is Li... 2018-03-31 23:58:12
#
#                                           url             user  \
# 0        /JMGayton1/status/980233135471214592        JMGayton1
# 1   /nohumanillegal/status/980233120401240065   nohumanillegal
# 2   /MsRachelPowell/status/980233027103072256   MsRachelPowell
# 3  /KevinARNG11BVet/status/980232921100570626  KevinARNG11BVet
# 4   /realJohnnyZipp/status/980232826523193344   realJohnnyZipp
#
#                                        original_text  \
# 0  Despite 45% being sexually assaulted/raped (22...
# 1  How Easter became a #MeToo moment\nhttps://www...
# 2  Praying and grateful for your strength! #metoo...
# 3  #MeToo not to diminish #MeToo but to say Me to...
# 4  CNN Article Claims That The Easter Story Is Li...
#
#                     hashtags       usernames  engagement
# 0                   [#METOO]              []          27
# 1                   [#MeToo]              []           0
# 2  [#metoo, #difficultwoman]              []           0
# 3           [#MeToo, #MeToo]              []           0
# 4                         []  [@dailycaller]           1
# ['data.pkl']

# %% [markdown]
# ### Tokenize and Stem

# %%
# nltk.download()

from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []

for i in data.text:
    allwords_stemmed = tokenize_and_stem(i) # for each item in 'data.text', tokenize/stem
    totalvocab_stemmed.extend(allwords_stemmed) # extend the 'totalvocab_stemmed' list
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
print('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
print()
print(totalvocab_stemmed[0:40])
print()
# print(vocab_frame.head(30))
# Out:
# there are 26193288 items in vocab_frame
#
# ['despit', 'be', 'sexual', 'assaulted/rap', 'by', 'staff', 'onli', 'report', 'to', 'polic', 'render', 'psych', 'ward', 'one', 'of', 'the', 'most', 'danger', 'place', 'imagin', 'mental', 'health', 'minist', 'foley', 'resist', 'women-on', 'ward', 'is', 'unaccept', 'how', 'easter', 'becam', 'a', 'moment', 'pray', 'and', 'grate', 'for', 'your', 'strength']

# %% [markdown]
# ### Tf-idf Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(
    analyzer='word', 
    tokenizer=tokenize_and_stem,
    stop_words='english', 
    min_df=0.0050, # word must be present in 0.5% of documents, or 50 documents of 10,000
    max_df=0.9900, # word cannot be present in 99% of documents, or 9,900 documents of 10,000
    ngram_range=(1,3)
)

X_tfidf_v = tfidf_vectorizer.fit_transform(data.text)

print(X_tfidf_v.shape)
# Out:
# (1392076, 348)

# %%
# print(tfidf_vectorizer.stop_words_)

# %%
print(tfidf_vectorizer.vocabulary_)
# Out:
# {'sexual': 258, 'onli': 212, 'report': 244, 'place': 224, 'moment': 196, 'say': 254, 'anoth': 21, 'abus': 2, 'articl': 25, 'claim': 61, 'stori': 287, 'like': 173, 'true': 306, "n't": 201, 'help': 137, 'feel': 105, 'ani': 20, 'white': 331, 'way': 326, 'address': 9, 'girl': 119, 'victim': 317, 'state': 283, 'movement': 199, 's': 251, 'think': 297, 'matter': 188, 'rape': 237, 'import': 146, 'everyon': 97, 'resign': 245, "'s": 1, 'assault': 27, 'sexual assault': 260, 'touch': 304, 'end': 93, 'watch': 325, 'campaign': 51, 'media': 191, 'need': 202, 'democrat': 80, 'mean': 190, 'told': 302, 'did': 82, "did n't": 83, 'share': 265, 'share stori': 266, 'time': 299, 'said': 253, 'alleg': 13, 'ca': 49, 'believ': 37, "ca n't": 50, 'real': 240, 'make': 183, 'veri': 316, 'feminist': 107, 'polit': 228, 'power': 230, 'world': 341, 'old': 211, 'whi': 330, 'twitter': 311, 'protect': 234, 'tweet': 310, 'account': 3, 'check': 58, 'becaus': 33, 'harass': 130, 'school': 255, 'shame': 264, 'person': 221, 'accus': 4, 'just': 156, 'blame': 42, 'countri': 70, 'hard': 131, 'black': 41, 'men': 192, 'alway': 16, 'stop': 286, 'star': 281, 'attack': 28, 'hope': 142, 'life': 171, 'allow': 14, 'come': 64, 'boy': 44, 'latest': 162, 'thank': 295, 'ask': 26, 'sex': 257, 'doe': 87, 'great': 125, 'care': 52, 'thought': 298, "doe n't": 88, 'm': 182, 'case': 54, 'turn': 309, 'fight': 108, 'woman': 333, 'best': 38, 'work': 339, 'equal': 94, 'women': 334, 'mayb': 189, "'m": 0, 'realli': 241, 'thing': 296, 'book': 43, 'daili': 75, 't': 292, 'mani': 186, 'justic': 157, 'gender': 118, 'trump': 307, 'lot': 180, 'befor': 35, 'got': 124, 'far': 103, 'public': 235, 'behavior': 36, 'yes': 345, 'vote': 321, 'right': 248, 'societi': 274, 'today': 300, "women 's": 335, 'wrong': 343, 'child': 59, 'light': 172, 'issu': 152, 'happen': 129, 'speak': 278, 'survivor': 291, 'start': 282, 'includ': 147, 'violenc': 319, 'use': 314, 'hashtag': 134, 'year': 344, 'age': 10, 'rememb': 243, 'alon': 15, 'lie': 170, 'guy': 127, 'know': 160, 'read': 239, 'misconduct': 194, 'support': 289, 'movi': 200, 'sexual misconduct': 262, 'pleas': 226, 'sign': 268, 'want': 324, 'join': 154, 'run': 250, 'man': 185, 'follow': 111, 'face': 100, 'tell': 294, 'era': 95, 'interview': 150, 'daughter': 77, 'talk': 293, 'new': 203, 'workplac': 340, 'don': 89, 'heard': 136, 'don t': 90, 'famili': 102, 'stand': 280, 'wonder': 337, 'becom': 34, 'learn': 165, 'respect': 246, 'clinton': 63, 'weinstein': 329, 'word': 338, 'fact': 101, 'good': 123, 'money': 197, 'wait': 322, 'listen': 174, 'presid': 232, 've': 315, 'long': 178, 'brave': 45, 'rapist': 238, 'final': 110, 'forc': 112, 'news': 205, 'job': 153, 'liber': 169, 'look': 179, 'reason': 242, 'ignor': 145, 'open': 213, 'march': 187, 'hollywood': 141, 'social': 272, 'social media': 273, 'understand': 313, 'law': 163, 'male': 184, 'apolog': 24, 'forward': 113, 'sad': 252, 'offic': 209, 'rt': 249, 'comment': 66, 'actual': 8, 'sexual harass': 261, 'american': 19, 'hand': 128, 'u': 312, 'busi': 48, 'hous': 143, 'america': 18, 'ladi': 161, 'noth': 207, 'messag': 193, 'past': 218, 'week': 328, 'act': 5, 'strong': 288, 'problem': 233, 'togeth': 301, 'speech': 279, 'peopl': 220, 'discuss': 85, 'women s': 336, 'tri': 305, 'silenc': 269, 'day': 78, 'friend': 116, 'post': 229, 'bring': 47, 'chang': 57, 'anyon': 22, 'femal': 106, 'film': 109, 'actress': 7, 'ago': 11, 'question': 236, 'kid': 158, 'better': 39, 'wear': 327, 'celebr': 56, 'respons': 247, 'sinc': 271, 'silent': 270, 'let': 167, 'love': 181, 'piec': 223, 'big': 40, 'predat': 231, 'creat': 73, 'industri': 148, 'pay': 219, 'sexual predat': 263, 'fuck': 117, 'defend': 79, 'harvey': 132, 'harvey weinstein': 133, 'donald': 91, 'someth': 276, 'night': 206, 'bad': 32, 'gone': 122, 'someon': 275, 'joke': 155, 'differ': 84, 'disgust': 86, 'award': 29, 'cultur': 74, 'amaz': 17, 'video': 318, 'backlash': 31, 'sorri': 277, 'shit': 267, 'away': 30, 'career': 53, 'break': 46, 'lead': 164, 'live': 176, 'guess': 126, 'experi': 98, 'pa ...

# %%
joblib.dump(tfidf_vectorizer, 'tfidf_vectorizer.pkl')
# Out:
# ['tfidf_vectorizer.pkl']

# %% [markdown]
# ### Run kmeans

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler(with_mean=False)
X = sc.fit_transform(X_tfidf_v)
print(X.shape)
# Out:
# (1392076, 348)

# %%
joblib.dump(X, 'X.pkl')
# Out:
# ['X.pkl']

# %%
from sklearn.cluster import KMeans
# from sklearn.metrics import silhouette_samples, silhouette_score

# %%
num_clusters = 425
kmeans = KMeans(n_clusters=num_clusters)
model = kmeans.fit(X)

print(kmeans.cluster_centers_)
print(kmeans.labels_.shape)

clusters = kmeans.labels_.tolist()
print(clusters[:10])
# Out:
# [[0.17531691 0.2590698  0.19265249 ... 0.11223534 0.         0.01696422]
#  [0.02490946 0.32915857 0.12886114 ... 0.01490448 0.         0.        ]
#  [0.         0.26466425 0.17740592 ... 0.00828306 0.         0.        ]
#  ...
#  [0.0673878  0.47804178 0.228185   ... 0.04230531 0.         0.02199367]
#  [0.15965446 0.25703716 0.19190393 ... 0.08934321 0.         0.02339985]
#  [0.09279151 0.2521577  0.12918645 ... 0.08269735 0.         0.00608201]]
# (1392076,)
# [13, 83, 19, 181, 39, 343, 329, 83, 361, 142]

# %%
data['cluster'] = clusters
print(data.head(3))
# Out:
#         fullname                                               html  \
# 0    Judy Gayton  <p class="TweetTextSize js-tweet-text tweet-te...
# 1          julie  <p class="TweetTextSize js-tweet-text tweet-te...
# 2  Rachel Powell  <p class="TweetTextSize js-tweet-text tweet-te...
#
#                    id  likes  replies  retweets  \
# 0  980233135471214592      6        1        10
# 1  980233120401240064      0        0         0
# 2  980233027103072256      0        0         0
#
#                                                 text           timestamp  \
# 0  Despite 45% being sexually assaulted/raped (22... 2018-03-31 23:59:26
# 1                     How Easter became a  moment\n  2018-03-31 23:59:22
# 2          Praying and grateful for your strength!   2018-03-31 23:59:00
#
#                                          url            user  \
# 0       /JMGayton1/status/980233135471214592       JMGayton1
# 1  /nohumanillegal/status/980233120401240065  nohumanillegal
# 2  /MsRachelPowell/status/980233027103072256  MsRachelPowell
#
#                                        original_text  \
# 0  Despite 45% being sexually assaulted/raped (22...
# 1  How Easter became a #MeToo moment\nhttps://www...
# 2  Praying and grateful for your strength! #metoo...
#
#                     hashtags usernames  engagement  cluster
# 0                   [#METOO]        []          27       13
# 1                   [#MeToo]        []           0       83
# 2  [#metoo, #difficultwoman]        []           0       19

# %%
joblib.dump(model, 'kmeans.pkl')
# Out:
# ['kmeans.pkl']

# %%
joblib.dump(data, 'data_clusters.pkl')
# Out:
# ['data_clusters.pkl']

# %% [markdown]
# ### Explore Results

# %%
{i: X[np.where(kmeans.labels_ == i)] for i in range(kmeans.n_clusters)}
# Out:
# {0: <3373x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17213 stored elements in Compressed Sparse Row format>,
#  1: <3093x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9232 stored elements in Compressed Sparse Row format>,
#  2: <765x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1122 stored elements in Compressed Sparse Row format>,
#  3: <3947x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12162 stored elements in Compressed Sparse Row format>,
#  4: <3777x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15808 stored elements in Compressed Sparse Row format>,
#  5: <3109x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13165 stored elements in Compressed Sparse Row format>,
#  6: <3994x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18555 stored elements in Compressed Sparse Row format>,
#  7: <5311x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 67773 stored elements in Compressed Sparse Row format>,
#  8: <665x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7598 stored elements in Compressed Sparse Row format>,
#  9: <1617x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9706 stored elements in Compressed Sparse Row format>,
#  10: <330x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2633 stored elements in Compressed Sparse Row format>,
#  11: <5448x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 40279 stored elements in Compressed Sparse Row format>,
#  12: <3391x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15656 stored elements in Compressed Sparse Row format>,
#  13: <4674x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29450 stored elements in Compressed Sparse Row format>,
#  14: <2394x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8817 stored elements in Compressed Sparse Row format>,
#  15: <3400x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10919 stored elements in Compressed Sparse Row format>,
#  16: <2897x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9716 stored elements in Compressed Sparse Row format>,
#  17: <2328x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9037 stored elements in Compressed Sparse Row format>,
#  18: <3791x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18302 stored elements in Compressed Sparse Row format>,
#  19: <81055x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16392 stored elements in Compressed Sparse Row format>,
#  20: <3584x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13193 stored elements in Compressed Sparse Row format>,
#  21: <3774x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15441 stored elements in Compressed Sparse Row format>,
#  22: <1706x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5090 stored elements in Compressed Sparse Row format>,
#  23: <6202x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 47866 stored elements in Compressed Sparse Row format>,
#  24: <1269x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3688 stored elements in Compressed Sparse Row format>,
#  25: <1813x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6162 stored elements in Compressed Sparse Row format>,
#  26: <3476x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17646 stored elements in Compressed Sparse Row format>,
#  27: <3093x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12570 stored elements in Compressed Sparse Row format>,
#  28: <4389x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23047 stored elements in Compressed Sparse Row format>,
#  29: <2666x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8577 stored elements in Compressed Sparse Row format>,
#  30: <4745x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28316 stored elements in Compressed Sparse Row format>,
#  31: <3440x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12203 stored elements in Compressed Sparse Row format>,
#  32: <3138x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14919 stored elements in Compressed Sparse Row format>,
#  33: <1762x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5260 stored elements in Compressed Sparse Row format>,
#  34: <3418x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20639 stored elements in Compressed Sparse Row format>,
#  35: <3204x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14483 stored elements in Compressed Sparse Row format>,
#  36: <3921x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15393 stored elements in Compressed Sparse Row format>,
#  37: <2757x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10799 stored elements in Compressed Sparse Row format>,
#  38: <383x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3893 stored elements in Compressed Sparse Row format>,
#  39: <3754x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17912 stored elements in Compressed Sparse Row format>,
#  40: <8618x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 61649 stored elements in Compressed Sparse Row format>,
#  41: <2601x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5426 stored elements in Compressed Sparse Row format>,
#  42: <3549x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12244 stored elements in Compressed Sparse Row format>,
#  43: <10301x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11746 stored elements in Compressed Sparse Row format>,
#  44: <3167x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8632 stored elements in Compressed Sparse Row format>,
#  45: <159x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1632 stored elements in Compressed Sparse Row format>,
#  46: <3145x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12945 stored elements in Compressed Sparse Row format>,
#  47: <3315x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18791 stored elements in Compressed Sparse Row format>,
#  48: <1618x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11362 stored elements in Compressed Sparse Row format>,
#  49: <3119x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13282 stored elements in Compressed Sparse Row format>,
#  50: <3255x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28231 stored elements in Compressed Sparse Row format>,
#  51: <4497x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24803 stored elements in Compressed Sparse Row format>,
#  52: <3315x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14534 stored elements in Compressed Sparse Row format>,
#  53: <16993x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37744 stored elements in Compressed Sparse Row format>,
#  54: <3980x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23255 stored elements in Compressed Sparse Row format>,
#  55: <4362x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25927 stored elements in Compressed Sparse Row format>,
#  56: <4133x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22233 stored elements in Compressed Sparse Row format>,
#  57: <3961x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22093 stored elements in Compressed Sparse Row format>,
#  58: <1669x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14022 stored elements in Compressed Sparse Row format>,
#  59: <3277x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 33817 stored elements in Compressed Sparse Row format>,
#  60: <3813x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19731 stored elements in Compressed Sparse Row format>,
#  61: <4489x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22913 stored elements in Compressed Sparse Row format>,
#  62: <1477x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3613 stored elements in Compressed Sparse Row format>,
#  63: <7752x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8387 stored elements in Compressed Sparse Row format>,
#  64: <5250x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8998 stored elements in Compressed Sparse Row format>,
#  65: <3544x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20369 stored elements in Compressed Sparse Row format>,
#  66: <5013x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30177 stored elements in Compressed Sparse Row format>,
#  67: <2068x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7622 stored elements in Compressed Sparse Row format>,
#  68: <4421x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25259 stored elements in Compressed Sparse Row format>,
#  69: <3419x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15775 stored elements in Compressed Sparse Row format>,
#  70: <3582x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15761 stored elements in Compressed Sparse Row format>,
#  71: <9705x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 90888 stored elements in Compressed Sparse Row format>,
#  72: <4511x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27190 stored elements in Compressed Sparse Row format>,
#  73: <4380x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25994 stored elements in Compressed Sparse Row format>,
#  74: <3116x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13765 stored elements in Compressed Sparse Row format>,
#  75: <2763x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9698 stored elements in Compressed Sparse Row format>,
#  76: <3357x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14137 stored elements in Compressed Sparse Row format>,
#  77: <1690x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7348 stored elements in Compressed Sparse Row format>,
#  78: <3159x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10884 stored elements in Compressed Sparse Row format>,
#  79: <1943x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7446 stored elements in Compressed Sparse Row format>,
#  80: <2777x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12360 stored elements in Compressed Sparse Row format>,
#  81: <3751x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16071 stored elements in Compressed Sparse Row format>,
#  82: <4437x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25877 stored elements in Compressed Sparse Row format>,
#  83: <6178x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9901 stored elements in Compressed Sparse Row format>,
#  84: <3805x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13635 stored elements in Compressed Sparse Row format>,
#  85: <3013x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13141 stored elements in Compressed Sparse Row format>,
#  86: <3024x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9896 stored elements in Compressed Sparse Row format>,
#  87: <2799x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9072 stored elements in Compressed Sparse Row format>,
#  88: <4257x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21876 stored elements in Compressed Sparse Row format>,
#  89: <159x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 690 stored elements in Compressed Sparse Row format>,
#  90: <2582x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12052 stored elements in Compressed Sparse Row format>,
#  91: <6137x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43716 stored elements in Compressed Sparse Row format>,
#  92: <4374x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9711 stored elements in Compressed Sparse Row format>,
#  93: <2684x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12895 stored elements in Compressed Sparse Row format>,
#  94: <4032x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20613 stored elements in Compressed Sparse Row format>,
#  95: <3591x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13792 stored elements in Compressed Sparse Row format>,
#  96: <3648x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 31256 stored elements in Compressed Sparse Row format>,
#  97: <5424x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 40633 stored elements in Compressed Sparse Row format>,
#  98: <3583x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18748 stored elements in Compressed Sparse Row format>,
#  99: <8410x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 60453 stored elements in Compressed Sparse Row format>,
#  100: <2283x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14238 stored elements in Compressed Sparse Row format>,
#  101: <598x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2572 stored elements in Compressed Sparse Row format>,
#  102: <3500x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15986 stored elements in Compressed Sparse Row format>,
#  103: <513x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2045 stored elements in Compressed Sparse Row format>,
#  104: <4083x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23509 stored elements in Compressed Sparse Row format>,
#  105: <1873x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16219 stored elements in Compressed Sparse Row format>,
#  106: <3519x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16214 stored elements in Compressed Sparse Row format>,
#  107: <3161x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13117 stored elements in Compressed Sparse Row format>,
#  108: <3237x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13289 stored elements in Compressed Sparse Row format>,
#  109: <4627x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27809 stored elements in Compressed Sparse Row format>,
#  110: <4883x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30461 stored elements in Compressed Sparse Row format>,
#  111: <4060x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21978 stored elements in Compressed Sparse Row format>,
#  112: <153x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1607 stored elements in Compressed Sparse Row format>,
#  113: <3777x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18985 stored elements in Compressed Sparse Row format>,
#  114: <4291x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7796 stored elements in Compressed Sparse Row format>,
#  115: <694x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2605 stored elements in Compressed Sparse Row format>,
#  116: <3491x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16679 stored elements in Compressed Sparse Row format>,
#  117: <4272x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23187 stored elements in Compressed Sparse Row format>,
#  118: <4323x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13267 stored elements in Compressed Sparse Row format>,
#  119: <1655x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6213 stored elements in Compressed Sparse Row format>,
#  120: <359x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3000 stored elements in Compressed Sparse Row format>,
#  121: <835x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4378 stored elements in Compressed Sparse Row format>,
#  122: <7240x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 47733 stored elements in Compressed Sparse Row format>,
#  123: <4044x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20102 stored elements in Compressed Sparse Row format>,
#  124: <4665x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28733 stored elements in Compressed Sparse Row format>,
#  125: <266x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1309 stored elements in Compressed Sparse Row format>,
#  126: <3672x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17236 stored elements in Compressed Sparse Row format>,
#  127: <3899x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17953 stored elements in Compressed Sparse Row format>,
#  128: <3089x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11670 stored elements in Compressed Sparse Row format>,
#  129: <3589x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18406 stored elements in Compressed Sparse Row format>,
#  130: <3322x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13582 stored elements in Compressed Sparse Row format>,
#  131: <2213x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19077 stored elements in Compressed Sparse Row format>,
#  132: <4325x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 25156 stored elements in Compressed Sparse Row format>,
#  133: <3096x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13087 stored elements in Compressed Sparse Row format>,
#  134: <3553x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7933 stored elements in Compressed Sparse Row format>,
#  135: <1905x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11777 stored elements in Compressed Sparse Row format>,
#  136: <3077x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11053 stored elements in Compressed Sparse Row format>,
#  137: <1579x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17252 stored elements in Compressed Sparse Row format>,
#  138: <2945x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14205 stored elements in Compressed Sparse Row format>,
#  139: <4622x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27362 stored elements in Compressed Sparse Row format>,
#  140: <4140x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23226 stored elements in Compressed Sparse Row format>,
#  141: <8537x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 81940 stored elements in Compressed Sparse Row format>,
#  142: <4828x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29230 stored elements in Compressed Sparse Row format>,
#  143: <5344x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36571 stored elements in Compressed Sparse Row format>,
#  144: <3060x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16828 stored elements in Compressed Sparse Row format>,
#  145: <2626x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10719 stored elements in Compressed Sparse Row format>,
#  146: <3260x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13511 stored elements in Compressed Sparse Row format>,
#  147: <1537x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5082 stored elements in Compressed Sparse Row format>,
#  148: <4994x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 35000 stored elements in Compressed Sparse Row format>,
#  149: <8850x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 45222 stored elements in Compressed Sparse Row format>,
#  150: <3072x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12179 stored elements in Compressed Sparse Row format>,
#  151: <4014x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21976 stored elements in Compressed Sparse Row format>,
#  152: <3296x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16331 stored elements in Compressed Sparse Row format>,
#  153: <32x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 251 stored elements in Compressed Sparse Row format>,
#  154: <3179x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11748 stored elements in Compressed Sparse Row format>,
#  155: <2791x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12138 stored elements in Compressed Sparse Row format>,
#  156: <3647x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18066 stored elements in Compressed Sparse Row format>,
#  157: <2708x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8790 stored elements in Compressed Sparse Row format>,
#  158: <4527x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27784 stored elements in Compressed Sparse Row format>,
#  159: <3781x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22978 stored elements in Compressed Sparse Row format>,
#  160: <2718x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10498 stored elements in Compressed Sparse Row format>,
#  161: <2143x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9995 stored elements in Compressed Sparse Row format>,
#  162: <3227x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11930 stored elements in Compressed Sparse Row format>,
#  163: <3050x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13996 stored elements in Compressed Sparse Row format>,
#  164: <499x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1503 stored elements in Compressed Sparse Row format>,
#  165: <2974x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8966 stored elements in Compressed Sparse Row format>,
#  166: <2980x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8923 stored elements in Compressed Sparse Row format>,
#  167: <1755x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7065 stored elements in Compressed Sparse Row format>,
#  168: <3277x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13717 stored elements in Compressed Sparse Row format>,
#  169: <3634x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20914 stored elements in Compressed Sparse Row format>,
#  170: <2936x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16606 stored elements in Compressed Sparse Row format>,
#  171: <3199x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11150 stored elements in Compressed Sparse Row format>,
#  172: <5671x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 42774 stored elements in Compressed Sparse Row format>,
#  173: <3461x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12774 stored elements in Compressed Sparse Row format>,
#  174: <4409x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 26870 stored elements in Compressed Sparse Row format>,
#  175: <2921x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7913 stored elements in Compressed Sparse Row format>,
#  176: <2668x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11347 stored elements in Compressed Sparse Row format>,
#  177: <4880x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29720 stored elements in Compressed Sparse Row format>,
#  178: <2900x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8349 stored elements in Compressed Sparse Row format>,
#  179: <4232x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 31764 stored elements in Compressed Sparse Row format>,
#  180: <1743x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6546 stored elements in Compressed Sparse Row format>,
#  181: <2560x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8418 stored elements in Compressed Sparse Row format>,
#  182: <1567x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4861 stored elements in Compressed Sparse Row format>,
#  183: <2761x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5534 stored elements in Compressed Sparse Row format>,
#  184: <6040x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15399 stored elements in Compressed Sparse Row format>,
#  185: <2528x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8657 stored elements in Compressed Sparse Row format>,
#  186: <2891x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11693 stored elements in Compressed Sparse Row format>,
#  187: <3966x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21889 stored elements in Compressed Sparse Row format>,
#  188: <484x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3637 stored elements in Compressed Sparse Row format>,
#  189: <3886x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17653 stored elements in Compressed Sparse Row format>,
#  190: <4230x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18952 stored elements in Compressed Sparse Row format>,
#  191: <2902x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9576 stored elements in Compressed Sparse Row format>,
#  192: <1061x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4247 stored elements in Compressed Sparse Row format>,
#  193: <2466x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9429 stored elements in Compressed Sparse Row format>,
#  194: <2815x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9342 stored elements in Compressed Sparse Row format>,
#  195: <5267x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 35209 stored elements in Compressed Sparse Row format>,
#  196: <2854x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14247 stored elements in Compressed Sparse Row format>,
#  197: <3517x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14561 stored elements in Compressed Sparse Row format>,
#  198: <2916x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12407 stored elements in Compressed Sparse Row format>,
#  199: <3026x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15015 stored elements in Compressed Sparse Row format>,
#  200: <4770x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29668 stored elements in Compressed Sparse Row format>,
#  201: <3672x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20027 stored elements in Compressed Sparse Row format>,
#  202: <3207x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13313 stored elements in Compressed Sparse Row format>,
#  203: <3827x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17247 stored elements in Compressed Sparse Row format>,
#  204: <71x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 663 stored elements in Compressed Sparse Row format>,
#  205: <451x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1784 stored elements in Compressed Sparse Row format>,
#  206: <3260x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17752 stored elements in Compressed Sparse Row format>,
#  207: <2570x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9748 stored elements in Compressed Sparse Row format>,
#  208: <4409x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27561 stored elements in Compressed Sparse Row format>,
#  209: <3102x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14060 stored elements in Compressed Sparse Row format>,
#  210: <1487x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6927 stored elements in Compressed Sparse Row format>,
#  211: <100x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 786 stored elements in Compressed Sparse Row format>,
#  212: <2987x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14250 stored elements in Compressed Sparse Row format>,
#  213: <2273x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7433 stored elements in Compressed Sparse Row format>,
#  214: <3078x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23098 stored elements in Compressed Sparse Row format>,
#  215: <300x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2358 stored elements in Compressed Sparse Row format>,
#  216: <2628x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9381 stored elements in Compressed Sparse Row format>,
#  217: <93x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 618 stored elements in Compressed Sparse Row format>,
#  218: <4143x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23027 stored elements in Compressed Sparse Row format>,
#  219: <2940x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19423 stored elements in Compressed Sparse Row format>,
#  220: <3146x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14038 stored elements in Compressed Sparse Row format>,
#  221: <3211x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7395 stored elements in Compressed Sparse Row format>,
#  222: <3303x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17177 stored elements in Compressed Sparse Row format>,
#  223: <2437x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19682 stored elements in Compressed Sparse Row format>,
#  224: <83x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 807 stored elements in Compressed Sparse Row format>,
#  225: <2587x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15700 stored elements in Compressed Sparse Row format>,
#  226: <3063x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16733 stored elements in Compressed Sparse Row format>,
#  227: <1513x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8112 stored elements in Compressed Sparse Row format>,
#  228: <3263x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17391 stored elements in Compressed Sparse Row format>,
#  229: <1918x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13715 stored elements in Compressed Sparse Row format>,
#  230: <3285x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16444 stored elements in Compressed Sparse Row format>,
#  231: <3122x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10616 stored elements in Compressed Sparse Row format>,
#  232: <2565x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7894 stored elements in Compressed Sparse Row format>,
#  233: <2974x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12806 stored elements in Compressed Sparse Row format>,
#  234: <3195x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15089 stored elements in Compressed Sparse Row format>,
#  235: <3287x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14224 stored elements in Compressed Sparse Row format>,
#  236: <2989x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13870 stored elements in Compressed Sparse Row format>,
#  237: <1807x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5246 stored elements in Compressed Sparse Row format>,
#  238: <2654x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9776 stored elements in Compressed Sparse Row format>,
#  239: <4095x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 36191 stored elements in Compressed Sparse Row format>,
#  240: <417x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2175 stored elements in Compressed Sparse Row format>,
#  241: <1619x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5488 stored elements in Compressed Sparse Row format>,
#  242: <786x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7314 stored elements in Compressed Sparse Row format>,
#  243: <3167x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11266 stored elements in Compressed Sparse Row format>,
#  244: <2506x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9203 stored elements in Compressed Sparse Row format>,
#  245: <3636x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16025 stored elements in Compressed Sparse Row format>,
#  246: <5391x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37146 stored elements in Compressed Sparse Row format>,
#  247: <3160x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9761 stored elements in Compressed Sparse Row format>,
#  248: <2805x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15853 stored elements in Compressed Sparse Row format>,
#  249: <2561x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8148 stored elements in Compressed Sparse Row format>,
#  250: <1755x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9108 stored elements in Compressed Sparse Row format>,
#  251: <2623x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14135 stored elements in Compressed Sparse Row format>,
#  252: <2915x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12924 stored elements in Compressed Sparse Row format>,
#  253: <3940x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 34749 stored elements in Compressed Sparse Row format>,
#  254: <903x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6859 stored elements in Compressed Sparse Row format>,
#  255: <2792x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10436 stored elements in Compressed Sparse Row format>,
#  256: <1834x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13270 stored elements in Compressed Sparse Row format>,
#  257: <3560x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16308 stored elements in Compressed Sparse Row format>,
#  258: <2688x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13034 stored elements in Compressed Sparse Row format>,
#  259: <2671x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11381 stored elements in Compressed Sparse Row format>,
#  260: <2159x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11146 stored elements in Compressed Sparse Row format>,
#  261: <293x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3921 stored elements in Compressed Sparse Row format>,
#  262: <2797x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9857 stored elements in Compressed Sparse Row format>,
#  263: <3010x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11660 stored elements in Compressed Sparse Row format>,
#  264: <3294x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15374 stored elements in Compressed Sparse Row format>,
#  265: <5434x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 38757 stored elements in Compressed Sparse Row format>,
#  266: <2680x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9909 stored elements in Compressed Sparse Row format>,
#  267: <3331x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 18823 stored elements in Compressed Sparse Row format>,
#  268: <3104x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16912 stored elements in Compressed Sparse Row format>,
#  269: <384x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2958 stored elements in Compressed Sparse Row format>,
#  270: <4503x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29391 stored elements in Compressed Sparse Row format>,
#  271: <3147x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14684 stored elements in Compressed Sparse Row format>,
#  272: <2815x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20673 stored elements in Compressed Sparse Row format>,
#  273: <2954x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13226 stored elements in Compressed Sparse Row format>,
#  274: <2665x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12520 stored elements in Compressed Sparse Row format>,
#  275: <4576x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 27840 stored elements in Compressed Sparse Row format>,
#  276: <2496x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11410 stored elements in Compressed Sparse Row format>,
#  277: <2872x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10832 stored elements in Compressed Sparse Row format>,
#  278: <2982x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13597 stored elements in Compressed Sparse Row format>,
#  279: <2996x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14212 stored elements in Compressed Sparse Row format>,
#  280: <4181x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 38138 stored elements in Compressed Sparse Row format>,
#  281: <3323x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17909 stored elements in Compressed Sparse Row format>,
#  282: <1821x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6796 stored elements in Compressed Sparse Row format>,
#  283: <3092x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13718 stored elements in Compressed Sparse Row format>,
#  284: <861x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7322 stored elements in Compressed Sparse Row format>,
#  285: <2991x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14097 stored elements in Compressed Sparse Row format>,
#  286: <3770x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19675 stored elements in Compressed Sparse Row format>,
#  287: <3491x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11187 stored elements in Compressed Sparse Row format>,
#  288: <3923x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22220 stored elements in Compressed Sparse Row format>,
#  289: <1758x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6487 stored elements in Compressed Sparse Row format>,
#  290: <1006x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7434 stored elements in Compressed Sparse Row format>,
#  291: <3350x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12785 stored elements in Compressed Sparse Row format>,
#  292: <1501x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3916 stored elements in Compressed Sparse Row format>,
#  293: <3081x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13734 stored elements in Compressed Sparse Row format>,
#  294: <3533x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8324 stored elements in Compressed Sparse Row format>,
#  295: <3987x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 41564 stored elements in Compressed Sparse Row format>,
#  296: <6484x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 43350 stored elements in Compressed Sparse Row format>,
#  297: <674x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5360 stored elements in Compressed Sparse Row format>,
#  298: <157x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1085 stored elements in Compressed Sparse Row format>,
#  299: <948x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6405 stored elements in Compressed Sparse Row format>,
#  300: <1573x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4265 stored elements in Compressed Sparse Row format>,
#  301: <3261x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16043 stored elements in Compressed Sparse Row format>,
#  302: <2524x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10133 stored elements in Compressed Sparse Row format>,
#  303: <1588x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4403 stored elements in Compressed Sparse Row format>,
#  304: <4782x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 29893 stored elements in Compressed Sparse Row format>,
#  305: <298x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2598 stored elements in Compressed Sparse Row format>,
#  306: <5217x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 37461 stored elements in Compressed Sparse Row format>,
#  307: <2425x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12331 stored elements in Compressed Sparse Row format>,
#  308: <3005x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24430 stored elements in Compressed Sparse Row format>,
#  309: <3243x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17721 stored elements in Compressed Sparse Row format>,
#  310: <3037x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14810 stored elements in Compressed Sparse Row format>,
#  311: <683x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2905 stored elements in Compressed Sparse Row format>,
#  312: <163x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 405 stored elements in Compressed Sparse Row format>,
#  313: <3221x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9214 stored elements in Compressed Sparse Row format>,
#  314: <2755x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10290 stored elements in Compressed Sparse Row format>,
#  315: <4859x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8019 stored elements in Compressed Sparse Row format>,
#  316: <285x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2019 stored elements in Compressed Sparse Row format>,
#  317: <1918x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7693 stored elements in Compressed Sparse Row format>,
#  318: <2726x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22646 stored elements in Compressed Sparse Row format>,
#  319: <3814x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19791 stored elements in Compressed Sparse Row format>,
#  320: <3449x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30550 stored elements in Compressed Sparse Row format>,
#  321: <42x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 308 stored elements in Compressed Sparse Row format>,
#  322: <1640x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5705 stored elements in Compressed Sparse Row format>,
#  323: <696x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3628 stored elements in Compressed Sparse Row format>,
#  324: <5478x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 39461 stored elements in Compressed Sparse Row format>,
#  325: <3455x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16083 stored elements in Compressed Sparse Row format>,
#  326: <1524x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3790 stored elements in Compressed Sparse Row format>,
#  327: <2351x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10304 stored elements in Compressed Sparse Row format>,
#  328: <3356x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8059 stored elements in Compressed Sparse Row format>,
#  329: <2793x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12395 stored elements in Compressed Sparse Row format>,
#  330: <2485x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17754 stored elements in Compressed Sparse Row format>,
#  331: <3641x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30330 stored elements in Compressed Sparse Row format>,
#  332: <4029x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22792 stored elements in Compressed Sparse Row format>,
#  333: <2102x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17053 stored elements in Compressed Sparse Row format>,
#  334: <3926x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 33557 stored elements in Compressed Sparse Row format>,
#  335: <1824x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3140 stored elements in Compressed Sparse Row format>,
#  336: <3936x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21699 stored elements in Compressed Sparse Row format>,
#  337: <2634x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8910 stored elements in Compressed Sparse Row format>,
#  338: <3740x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28636 stored elements in Compressed Sparse Row format>,
#  339: <2999x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12449 stored elements in Compressed Sparse Row format>,
#  340: <3644x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17088 stored elements in Compressed Sparse Row format>,
#  341: <4502x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8896 stored elements in Compressed Sparse Row format>,
#  342: <3213x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28127 stored elements in Compressed Sparse Row format>,
#  343: <3394x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16153 stored elements in Compressed Sparse Row format>,
#  344: <4048x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23387 stored elements in Compressed Sparse Row format>,
#  345: <286x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1374 stored elements in Compressed Sparse Row format>,
#  346: <2711x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8535 stored elements in Compressed Sparse Row format>,
#  347: <4674x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28572 stored elements in Compressed Sparse Row format>,
#  348: <4184x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20928 stored elements in Compressed Sparse Row format>,
#  349: <4294x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23909 stored elements in Compressed Sparse Row format>,
#  350: <80x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 423 stored elements in Compressed Sparse Row format>,
#  351: <3071x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10154 stored elements in Compressed Sparse Row format>,
#  352: <91x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 472 stored elements in Compressed Sparse Row format>,
#  353: <4370x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22985 stored elements in Compressed Sparse Row format>,
#  354: <2553x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17451 stored elements in Compressed Sparse Row format>,
#  355: <1453x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9327 stored elements in Compressed Sparse Row format>,
#  356: <4735x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 45680 stored elements in Compressed Sparse Row format>,
#  357: <4085x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24362 stored elements in Compressed Sparse Row format>,
#  358: <114x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 734 stored elements in Compressed Sparse Row format>,
#  359: <3410x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21037 stored elements in Compressed Sparse Row format>,
#  360: <1345x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2770 stored elements in Compressed Sparse Row format>,
#  361: <1468x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3376 stored elements in Compressed Sparse Row format>,
#  362: <2784x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10742 stored elements in Compressed Sparse Row format>,
#  363: <2958x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11569 stored elements in Compressed Sparse Row format>,
#  364: <5057x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32043 stored elements in Compressed Sparse Row format>,
#  365: <2714x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10964 stored elements in Compressed Sparse Row format>,
#  366: <1893x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17219 stored elements in Compressed Sparse Row format>,
#  367: <4744x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32536 stored elements in Compressed Sparse Row format>,
#  368: <2612x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5025 stored elements in Compressed Sparse Row format>,
#  369: <3737x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30896 stored elements in Compressed Sparse Row format>,
#  370: <2646x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8578 stored elements in Compressed Sparse Row format>,
#  371: <1107x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8527 stored elements in Compressed Sparse Row format>,
#  372: <3645x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21025 stored elements in Compressed Sparse Row format>,
#  373: <1474x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4300 stored elements in Compressed Sparse Row format>,
#  374: <2065x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8031 stored elements in Compressed Sparse Row format>,
#  375: <3928x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24649 stored elements in Compressed Sparse Row format>,
#  376: <2910x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11061 stored elements in Compressed Sparse Row format>,
#  377: <6872x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 77433 stored elements in Compressed Sparse Row format>,
#  378: <3215x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9097 stored elements in Compressed Sparse Row format>,
#  379: <3904x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20556 stored elements in Compressed Sparse Row format>,
#  380: <3107x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16738 stored elements in Compressed Sparse Row format>,
#  381: <395x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3136 stored elements in Compressed Sparse Row format>,
#  382: <233x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1287 stored elements in Compressed Sparse Row format>,
#  383: <165x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1423 stored elements in Compressed Sparse Row format>,
#  384: <1528x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5295 stored elements in Compressed Sparse Row format>,
#  385: <5345x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 32681 stored elements in Compressed Sparse Row format>,
#  386: <7177x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 58478 stored elements in Compressed Sparse Row format>,
#  387: <1903x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9845 stored elements in Compressed Sparse Row format>,
#  388: <3936x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20485 stored elements in Compressed Sparse Row format>,
#  389: <2479x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10615 stored elements in Compressed Sparse Row format>,
#  390: <3477x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16643 stored elements in Compressed Sparse Row format>,
#  391: <3702x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20654 stored elements in Compressed Sparse Row format>,
#  392: <3468x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16818 stored elements in Compressed Sparse Row format>,
#  393: <3671x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9023 stored elements in Compressed Sparse Row format>,
#  394: <1732x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7475 stored elements in Compressed Sparse Row format>,
#  395: <3210x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 23984 stored elements in Compressed Sparse Row format>,
#  396: <3119x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 24139 stored elements in Compressed Sparse Row format>,
#  397: <3402x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19929 stored elements in Compressed Sparse Row format>,
#  398: <1114x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10362 stored elements in Compressed Sparse Row format>,
#  399: <3088x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17980 stored elements in Compressed Sparse Row format>,
#  400: <1732x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4488 stored elements in Compressed Sparse Row format>,
#  401: <2593x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10263 stored elements in Compressed Sparse Row format>,
#  402: <1632x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6174 stored elements in Compressed Sparse Row format>,
#  403: <355x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1534 stored elements in Compressed Sparse Row format>,
#  404: <2436x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10861 stored elements in Compressed Sparse Row format>,
#  405: <480x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 2458 stored elements in Compressed Sparse Row format>,
#  406: <3540x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20378 stored elements in Compressed Sparse Row format>,
#  407: <4176x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12931 stored elements in Compressed Sparse Row format>,
#  408: <3263x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 22978 stored elements in Compressed Sparse Row format>,
#  409: <13620x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 127488 stored elements in Compressed Sparse Row format>,
#  410: <3841x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21543 stored elements in Compressed Sparse Row format>,
#  411: <234x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1632 stored elements in Compressed Sparse Row format>,
#  412: <954x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6353 stored elements in Compressed Sparse Row format>,
#  413: <456x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4665 stored elements in Compressed Sparse Row format>,
#  414: <3557x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 30609 stored elements in Compressed Sparse Row format>,
#  415: <2853x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12876 stored elements in Compressed Sparse Row format>,
#  416: <7999x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 47722 stored elements in Compressed Sparse Row format>,
#  417: <1565x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4288 stored elements in Compressed Sparse Row format>,
#  418: <268x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1754 stored elements in Compressed Sparse Row format>,
#  419: <1224x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 3578 stored elements in Compressed Sparse Row format>,
#  420: <1631x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5528 stored elements in Compressed Sparse Row format>,
#  421: <1532x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11295 stored elements in Compressed Sparse Row format>,
#  422: <2687x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13079 stored elements in Compressed Sparse Row format>,
#  423: <3616x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 19930 stored elements in Compressed Sparse Row format>,
#  424: <2567x348 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10690 stored elements in Compressed Sparse Row format>}

# %%
print(X[np.where(kmeans.labels_ == 0)].shape)
print(X.shape)
# Out:
# (3373, 348)
# (1392076, 348)

# %%
cluster_count = data.groupby(['cluster'])['cluster'].count()
cluster_count = pd.DataFrame(dict(cluster=cluster_count.index, count=cluster_count.values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-195-99640931a870> in <module>()
#       1 cluster_count = data.groupby(['cluster'])['cluster'].count()
#       2 cluster_count = pd.DataFrame(dict(cluster=cluster_count.index, count=cluster_count.values))
# ----> 3 cluster_count(head)
#
# NameError: name 'head' is not defined

# %%
cluster_count.head()
# Out:
#    cluster  count
# 0        0   3373
# 1        1   3093
# 2        2    765
# 3        3   3947
# 4        4   3777

# %%
cluster_count.to_csv('cluster_count.csv', index=False)

# %%
terms = tfidf_vectorizer.get_feature_names()

# %%
from __future__ import print_function

print("Top terms per cluster:")
print()

#sort cluster centers by proximity to centroid
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-5] 


for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :10]: #replace 6 with n words per cluster
        print(' %s' % vocab_frame.loc[terms[ind].split(' ')].values.tolist()[0][0], end=',')
        
    print() #add whitespace
    print() #add whitespace
# Out:
# Top terms per cluster:
#
# Cluster 0 words: finally, hopes, people, story, sexually, started, got, making, believe, truth,
#
# Cluster 1 words: talks, why, women, thing, sexually, did, making, know, person, help,
#
# Cluster 2 words: sexually, woman, thing, forced, shares, men, joke, equally, t, yes,
#
# Cluster 3 words: posts, read, movement, 've, n't, years, shares, man, because, supporting,
#
# Cluster 4 words: industry, changing, n't, female, work, abuse, media, children, issue, sex,
#
# Cluster 5 words: believe, supporting, why, say, trump, movement, like, think, person, assaulted,
#
# Cluster 6 words: star, movement, talks, say, lady, awards, hits, feminist, turns, reported,
#
# Cluster 7 words: come, victims, story, sexually, feel, 's, shares, just, woman, shameful,
#
# Cluster 8 words: don, s, women, needs, just, people, rights, thing, lie, really,
#
# Cluster 9 words: long, thanks, read, times, does, free, girls, feel, every, exposes,
#
# Cluster 10 words: new, new, maybe, world, lie, good, way, trump, fear, feminist,
#
# Cluster 11 words: career, alleged, accusations, say, lives, woman, job, political, assaulted, t,
#
# Cluster 12 words: america, trump, president, great, sexually, female, rape, only, world, new,
#
# Cluster 13 words: places, big, sexually, only, just, abuse, started, feel, very, heard,
#
# Cluster 14 words: wants, just, victims, think, why, shares, because, guy, believe, harassing,
#
# Cluster 15 words: world, daily, why, needs, power, times, woman, n't, only, because,
#
# Cluster 16 words: good, read, times, day, like, 'm, only, supporting, guy, many,
#
# Cluster 17 words: victims, 's, women, only, forced, use, shameful, blaming, stop, sexually,
#
# Cluster 18 words: book, before, sexually, women, story, needs, abuse, please, political, survivors,
#
# Cluster 19 words: women, woman, tell, harassing, silence, think, times, why, let, use,
#
# Cluster 20 words: check, video, 'm, good, weeks, great, just, better, sexually, men,
#
# Cluster 21 words: business, daily, nyt, times, story, protected, discuss, why, work, stand,
#
# Cluster 22 words: cases, era, misconduct, sexually, n't, like, t, before, women, rights,
#
# Cluster 23 words: women, rights, men, backlash, nyt, experiences, since, political, female, words,
#
# Cluster 24 words: american, stop, needs, daily, hollywood, t, shameful, becoming, new, moment,
#
# Cluster 25 words: does, know, work, story, only, needs, man, moment, campaign, victims,
#
# Cluster 26 words: job, sexually, another, t, did, woman, every, people, reported, needs,
#
# Cluster 27 words: discuss, today, help, 's, new, happening, era, public, love, moment,
#
# Cluster 28 words: amazing, real, strong, men, just, today, words, everyone, great, important,
#
# Cluster 29 words: thought, read, s, think, story, n't, asking, believe, moment, 'm,
#
# Cluster 30 words: wear, democrat, movement, actresses, hollywood, like, every, assaulted, day, celebrities,
#
# Cluster 31 words: responsible, tweets, age, m, campaign, making, victims, needs, people, 've,
#
# Cluster 32 words: action, say, 's, hollywood, sex, becoming, hashtag, victims, today, started,
#
# Cluster 33 words: wondering, movement, women, feel, news, did, times, supporting, girls, got,
#
# Cluster 34 words: equally, fight, changing, wants, work, like, everyone, power, help, creating,
#
# Cluster 35 words: laws, state, new, women, cases, work, political, rights, assaulted, help,
#
# Cluster 36 words: hashtag, sexually, 's, like, s, join, victims, campaign, because, read,
#
# Cluster 37 words: resign, needs, moment, sexually, rape, political, come, misconduct, 'm, supporting,
#
# Cluster 38 words: ca, speak, say, silent, why, family, woman, brave, think, defends,
#
# Cluster 39 words: article, important, 's, new, responsible, culture, comment, 've, say, daily,
#
# Cluster 40 words: harvey, say, career, oscars, actresses, harassing, deserves, new, rape, claims,
#
# Cluster 41 words: like, 's, making, person, shares, sexually, sex, man, love, rights,
#
# Cluster 42 words: rt, movement, campaign, world, wants, sex, help, new, look, speak,
#
# Cluster 43 words: movement, n't, thing, just, silence, why, did, say, turns, feminist,
#
# Cluster 44 words: love, women, men, s, shares, think, only, tell, person, read,
#
# Cluster 45 words: sexually, holding, resign, 's, political, house, any, people, victims, day,
#
# Cluster 46 words: weeks, watch, moment, news, harassing, posts, today, political, sexually, end,
#
# Cluster 47 words: respect, voices, like, say, wants, speak, everyone, 've, sexually, abuse,
#
# Cluster 48 words: golden, power, address, like, new, truth, say, little, speak, means,
#
# Cluster 49 words: clinton, campaign, questions, victims, abuse, why, face, assaulted, sexually, world,
#
# Cluster 50 words: maybe, like, 've, know, t, actually, say, many, thought, story,
#
# Cluster 51 words: donald, america, turns, times, tried, behavior, use, news, sex, clinton,
#
# Cluster 52 words: bring, movement, watch, women, needs, like, just, assaulted, say, t,
#
# Cluster 53 words: daily, s, silence, women, tried, thing, love, harassing, supporting, feel,
#
# Cluster 54 words: told, said, 've, did, asking, job, assaulted, words, male, day,
#
# Cluster 55 words: money, just, like, movement, needs, true, t, actresses, away, think,
#
# Cluster 56 words: left, why, age, only, changing, feel, men, woman, man, think,
#
# Cluster 57 words: boys, old, 's, started, just, culture, young, era, think, s,
#
# Cluster 58 words: globe, awards, men, celebrities, stand, join, people, years, t, best,
#
# Cluster 59 words: misconduct, claims, movement, reported, since, victims, any, president, donald, power,
#
# Cluster 60 words: officers, sexually, work, assaulted, sex, laws, started, public, workplace, reported,
#
# Cluster 61 words: movie, star, sexually, movement, sexually, great, abuse, industry, n't, good,
#
# Cluster 62 words: alone, say, movement, m, thanks, remembered, wants, think, 've, man,
#
# Cluster 63 words: latest, women, sexually, assaulted, girls, forward, film, don, equally, exposes,
#
# Cluster 64 words: thanks, movement, making, abuse, speak, brave, tried, sexually, many, heard,
#
# Cluster 65 words: franken, investigation, stay, movement, apologize, believe, rights, agree, does, say,
#
# Cluster 66 words: during, book, black, stand, speech, world, talks, discuss, abuse, watch,
#
# Cluster 67 words: let, women, harassing, men, victims, people, times, children, work, think,
#
# Cluster 68 words: little, like, women, know, abuse, movement, look, does, because, sexually,
#
# Cluster 69 words: film, oscars, sexually, hopes, age, making, discuss, story, reported, black,
#
# Cluster 70 words: play, woman, culture, work, men, just, times, discuss, why, tell,
#
# Cluster 71 words: did, wants, anything, like, tell, making, care, anyone, ago, something,
#
# Cluster 72 words: attacks, woman, rape, 's, another, male, supporting, only, person, way,
#
# Cluster 73 words: cause, just, movement, know, many, any, problem, assaulted, great, really,
#
# Cluster 74 words: reported, hollywood, rape, new, why, accusations, s, only, times, woman,
#
# Cluster 75 words: oh, good, please, movement, way, thought, use, 've, guy, something,
#
# Cluster 76 words: march, assaulted, today, s, people, trump, day, news, times, stop,
#
# Cluster 77 words: social, movement, sexually, feminist, like, new, s, story, thanks, asking,
#
# Cluster 78 words: means, male, changing, women, say, like, only, rights, thing, happening,
#
# Cluster 79 words: far, 've, men, just, person, times, life, assaulted, thought, say,
#
# Cluster 80 words: stay, sex, men, why, moment, friend, way, hopes, think, follow,
#
# Cluster 81 words: house, harassing, state, abuse, president, lives, america, tried, end, good,
#
# Cluster 82 words: daughter, abuse, women, tell, because, watch, trump, stand, think, thing,
#
# Cluster 83 words: moment, women, story, assaulted, thing, children, silence, 'm, asking, 've,
#
# Cluster 84 words: hits, resign, movement, political, alleged, rights, only, thing, speak, assaulted,
#
# Cluster 85 words: twitter, assaulted, justice, tweets, watch, today, people, started, friend, many,
#
# Cluster 86 words: comment, 's, backlash, read, trump, n't, thought, video, campaign, new,
#
# Cluster 87 words: tweets, years, did, many, movement, supporting, harassing, victims, why, tell,
#
# Cluster 88 words: hey, check, women, girls, did, maybe, assaulted, come, say, making,
#
# Cluster 89 words: everyone, very, hopes, public, lie, amazing, important, check, look, love,
#
# Cluster 90 words: vote, please, open, moore, needs, s, talks, because, person, say,
#
# Cluster 91 words: women, rights, men, join, world, n't, many, black, story, like,
#
# Cluster 92 words: backlash, women, needs, think, people, started, reported, sexually, trump, power,
#
# Cluster 93 words: points, just, woman, harassing, needs, people, any, only, assaulted, abuse,
#
# Cluster 94 words: breaking, women, abuse, help, times, people, culture, video, open, needs,
#
# Cluster 95 words: feminist, rape, world, victims, moment, watch, supporting, wants, read, weinstein,
#
# Cluster 96 words: deserves, justice, people, abuse, person, rights, just, men, times, did,
#
# Cluster 97 words: clear, wants, harassing, sexually, thing, victims, cases, let, supporting, issue,
#
# Cluster 98 words: cover, movement, new, use, black, started, got, sexually, needs, did,
#
# Cluster 99 words: shares, senators, together, survivors, abuse, book, know, 's, experiences, work,
#
# Cluster 100 words: gone, s, many, know, needs, thing, before, t, feel, think,
#
# Cluster 101 words: oscars, making, s, day, way, reported, winning, since, really, open,
#
# Cluster 102 words: golden, celebrities, moment, times, years, watch, video, victims, n't, say,
#
# Cluster 103 words: someone, little, sexually, latest, film, forward, kind, does, end, leading,
#
# Cluster 104 words: disgusting, s, abuse, use, fucked, m, supporting, many, know, nothing,
#
# Cluster 105 words: holding, abuse, continue, changing, times, violence, s, way, sexually, started,
#
# Cluster 106 words: hear, believe, love, sexually, n't, think, like, assaulted, woman, sexually,
#
# Cluster 107 words: fucked, guy, shit, women, s, think, tell, love, rape, come,
#
# Cluster 108 words: words, 's, say, movement, please, survivors, day, feminist, really, harassing,
#
# Cluster 109 words: leading, 's, harassing, means, hopes, era, female, needs, world, action,
#
# Cluster 110 words: human, gender, sexually, violence, equally, another, n't, times, sex, children,
#
# Cluster 111 words: step, sexually, times, say, s, world, brave, people, way, action,
#
# Cluster 112 words: let, political, continue, good, date, know, look, hopes, 've, power,
#
# Cluster 113 words: questions, believe, m, 's, sexually, important, anyone, t, very, work,
#
# Cluster 114 words: say, n't, only, tried, like, tell, sexually, many, stop, stand,
#
# Cluster 115 words: apologize, sexually, said, sign, campaign, issue, guy, thing, stand, woman,
#
# Cluster 116 words: learning, sexually, 've, men, read, join, person, work, lives, making,
#
# Cluster 117 words: joke, rape, assaulted, like, t, because, away, man, turns, only,
#
# Cluster 118 words: video, new, thought, alleged, sexually, think, world, times, tell, campaign,
#
# Cluster 119 words: silent, times, silence, harassing, 've, story, any, blaming, way, industry,
#
# Cluster 120 words: brave, inspired, woman, believe, sadly, supporting, know, read, today, sexually,
#
# Cluster 121 words: awards, rapist, winning, moment, alleged, times, abuse, sexually, end, points,
#
# Cluster 122 words: person, movement, s, includes, making, campaign, rt, finally, 've, power,
#
# Cluster 123 words: best, oscars, way, women, movement, people, times, making, come, day,
#
# Cluster 124 words: date, guy, women, tried, n't, light, s, because, before, world,
#
# Cluster 125 words: night, political, movement, thought, years, women, every, accusations, like, harassing,
#
# Cluster 126 words: message, trump, tried, say, sexually, love, just, survivors, help, use,
#
# Cluster 127 words: opinion, clinton, women, anyone, wants, moment, just, m, voices, man,
#
# Cluster 128 words: becoming, help, public, campaign, thing, world, needs, look, speak, sexually,
#
# Cluster 129 words: sadly, women, really, truth, 'm, read, every, day, 've, t,
#
# Cluster 130 words: includes, wants, sexually, years, does, discuss, video, story, power, t,
#
# Cluster 131 words: u, just, t, shameful, thanks, feel, assaulted, look, guy, harassing,
#
# Cluster 132 words: ignored, video, say, abuse, 's, industry, real, stop, woman, violence,
#
# Cluster 133 words: kids, help, sign, child, sexually, video, tried, play, friend, harassing,
#
# Cluster 134 words: why, men, abuse, only, thing, children, person, many, know, important,
#
# Cluster 135 words: great, work, think, supporting, talks, look, help, many, story, power,
#
# Cluster 136 words: started, women, s, day, way, talks, 'm, many, use, story,
#
# Cluster 137 words: don, m, like, understand, movement, agree, woman, 'll, way, story,
#
# Cluster 138 words: voices, movement, help, survivors, world, times, abuse, please, new, woman,
#
# Cluster 139 words: exposes, sexually, men, s, finally, needs, reported, just, sexually, help,
#
# Cluster 140 words: running, 's, forced, think, s, n't, men, campaign, thing, man,
#
# Cluster 141 words: does, because, wants, happening, people, sexually, victims, why, deserves, facts,
#
# Cluster 142 words: address, problem, industry, s, assaulted, say, light, way, men, people,
#
# Cluster 143 words: past, weeks, behavior, way, assaulted, light, n't, celebrities, making, work,
#
# Cluster 144 words: gone, n't, like, lives, actresses, asking, just, new, opinion, every,
#
# Cluster 145 words: use, women, abuse, just, man, speak, needs, person, 'm, love,
#
# Cluster 146 words: 'm, n't, sure, talks, why, women, 've, look, years, believe,
#
# Cluster 147 words: courage, stand, inspired, great, hopes, supporting, respect, face, happening, people,
#
# Cluster 148 words: understand, men, help, movement, harassing, because, woman, thing, posts, different,
#
# Cluster 149 words: sexually, assaulted, say, victims, n't, hollywood, abuse, way, like, years,
#
# Cluster 150 words: life, moment, changing, love, woman, times, rights, day, men, s,
#
# Cluster 151 words: remembered, think, video, assaulted, rape, like, hard, many, guy, harassing,
#
# Cluster 152 words: fight, stand, love, help, assaulted, girls, end, times, years, why,
#
# Cluster 153 words: write, cases, actually, good, really, sexually, hands, laws, claims, wear,
#
# Cluster 154 words: follow, please, posts, harassing, just, workplace, 'm, comment, got, because,
#
# Cluster 155 words: state, sexually, use, supporting, moment, alleged, only, speak, job, public,
#
# Cluster 156 words: light, help, sexually, abuse, 's, women, think, sign, like, only,
#
# Cluster 157 words: speak, silence, needs, story, woman, just, sexually, tell, moment, person,
#
# Cluster 158 words: blaming, shameful, weinstein, assaulted, always, abuse, movement, thing, anyone, say,
#
# Cluster 159 words: moore, end, forced, believe, like, girls, political, use, needs, think,
#
# Cluster 160 words: changing, thing, only, making, wants, story, just, speak, shares, laws,
#
# Cluster 161 words: people, making, say, tried, women, story, person, shares, men, speak,
#
# Cluster 162 words: open, new, sexually, harassing, campaign, another, age, people, say, survivors,
#
# Cluster 163 words: truth, know, voices, needs, silence, men, love, thing, wants, violence,
#
# Cluster 164 words: winning, best, years, n't, fight, forward, gender, gone, donald, era,
#
# Cluster 165 words: supporting, 's, people, s, like, please, winning, predation, silence, anyone,
#
# Cluster 166 words: read, why, moment, just, women, times, thing, rights, years, please,
#
# Cluster 167 words: fear, stop, movement, shameful, wake, cause, feel, power, workplace, alone,
#
# Cluster 168 words: real, era, does, s, world, n't, talks, woman, age, lives,
#
# Cluster 169 words: strong, voices, speak, making, people, 'm, very, say, changing, tell,
#
# Cluster 170 words: 've, tell, women, s, read, abuse, victims, movement, children, shares,
#
# Cluster 171 words: alleged, movement, say, t, women, victims, forced, n't, political, like,
#
# Cluster 172 words: facts, 's, men, like, assaulted, look, victims, believe, truth, years,
#
# Cluster 173 words: please, needs, wants, know, sign, campaign, movement, harassing, sexually, thing,
#
# Cluster 174 words: act, victims, 's, video, sexually, way, rape, only, shameful, learning,
#
# Cluster 175 words: trump, s, silence, story, abuse, needs, resign, tweets, men, another,
# Cluster 176 words: man, women, s, men, power, sex, times, way, victims, read,
#
# Cluster 177 words: country, every, moment, culture, like, trump, new, just, men, know,
#
# Cluster 178 words: oscars, era, t, accusations, happening, winning, got, posts, supporting, best,
#
# Cluster 179 words: new, golden, industry, harvey, points, address, news, women, state, era,
#
# Cluster 180 words: deserves, nothing, work, cover, stand, 's, believe, years, did, abuse,
#
# Cluster 181 words: another, way, movement, look, come, sexually, sexually, rape, campaign, tell,
#
# Cluster 182 words: shit, know, twitter, needs, latest, hits, guy, use, talks, lot,
#
# Cluster 183 words: just, women, times, abuse, children, shares, many, really, watch, man,
#
# Cluster 184 words: news, 's, harassing, s, new, just, n't, forced, come, tried,
#
# Cluster 185 words: way, work, changing, like, woman, people, 'm, power, moment, years,
#
# Cluster 186 words: sign, women, actresses, sexually, march, sexually, look, know, asking, violence,
#
# Cluster 187 words: hard, tried, people, say, come, because, man, tell, thing, needs,
#
# Cluster 188 words: ago, woman, movement, men, white, s, feminist, celebrities, person, n't,
#
# Cluster 189 words: interview, listening, new, today, survivors, harassing, thanks, hopes, hear, experiences,
#
# Cluster 190 words: wake, fight, alleged, hits, weinstein, sexually, story, culture, times, world,
#
# Cluster 191 words: stand, supporting, abuse, know, man, s, power, t, story, only,
#
# Cluster 192 words: twitter, fucked, behavior, violence, today, 've, think, come, end, franken,
#
# Cluster 193 words: know, 's, thing, only, person, victims, someone, shares, sexually, let,
#
# Cluster 194 words: join, today, forced, 's, speak, new, needs, day, many, backlash,
#
# Cluster 195 words: took, just, courage, movement, did, 's, someone, words, s, woman,
#
# Cluster 196 words: long, 've, women, really, say, needs, like, t, era, story,
#
# Cluster 197 words: conversation, story, needs, movement, wants, why, help, culture, just, very,
#
# Cluster 198 words: better, know, times, way, like, hopes, sex, every, harassing, tried,
#
# Cluster 199 words: 'll, like, watch, movement, come, women, stop, lives, something, tweets,
#
# Cluster 200 words: liberalism, feminist, sexually, s, woman, got, use, harassing, nothing, wants,
#
# Cluster 201 words: old, times, men, sexually, happening, say, started, s, story, tell,
#
# Cluster 202 words: end, sexually, started, abuse, say, men, n't, means, supporting, did,
#
# Cluster 203 words: listening, new, discuss, just, voices, s, rights, know, stop, started,
#
# Cluster 204 words: defends, child, people, campaign, matters, t, s, man, speak, trump,
#
# Cluster 205 words: golden, like, making, follow, celebrities, wrong, hits, s, women, sexually,
#
# Cluster 206 words: white, woman, man, era, another, feminist, why, tried, look, think,
#
# Cluster 207 words: hopes, women, come, story, 'm, speak, supporting, love, watch, t,
#
# Cluster 208 words: ca, believe, because, making, men, any, care, speak, use, person,
#
# Cluster 209 words: important, many, come, thanks, women, needs, times, power, era, today,
#
# Cluster 210 words: predation, men, another, many, n't, every, people, say, because, times,
#
# Cluster 211 words: wait, accusations, senators, times, t, tell, silent, only, 's, agree,
#
# Cluster 212 words: shameful, public, use, sexually, n't, say, only, story, sex, happening,
#
# Cluster 213 words: did, just, think, woman, t, men, accusations, feel, because, yes,
#
# Cluster 214 words: lady, just, love, stand, let, come, say, any, thing, told,
#
# Cluster 215 words: continue, exposes, supporting, started, many, fight, everyone, only, 's, abuse,
#
# Cluster 216 words: actresses, apologize, moment, 's, harassing, women, play, rt, public, times,
#
# Cluster 217 words: inspired, love, times, play, women, hopes, speak, words, way, talks,
#
# Cluster 218 words: rapist, protected, 's, why, women, n't, stop, attacks, sex, believe,
#
# Cluster 219 words: guess, men, tweets, 'll, movement, play, really, got, man, victims,
#
# Cluster 220 words: stop, sexually, times, tried, talks, why, s, children, power, supporting,
#
# Cluster 221 words: campaign, supporting, s, new, abuse, trump, only, work, know, assaulted,
#
# Cluster 222 words: always, love, n't, why, friend, making, someone, t, wants, guy,
#
# Cluster 223 words: cases, rape, abuse, s, wondering, know, because, public, men, real,
#
# Cluster 224 words: allow, girls, continue, stop, s, does, anyone, needs, ca, face,
#
# Cluster 225 words: face, sexually, alleged, 's, join, new, life, work, reported, issue,
#
# Cluster 226 words: lie, accusations, say, know, s, lives, only, does, why, work,
#
# Cluster 227 words: age, sexually, times, s, sexually, girls, why, t, supporting, just,
#
# Cluster 228 words: protected, harassing, sexually, person, stop, workplace, s, business, many, times,
#
# Cluster 229 words: president, state, resign, harassing, like, making, does, think, includes, way,
#
# Cluster 230 words: gender, conversation, men, age, nyt, talks, join, political, does, needs,
#
# Cluster 231 words: yes, please, era, s, movement, silence, know, 've, tell, day,
#
# Cluster 232 words: rights, movement, tell, why, supporting, n't, come, rape, accusations, shares,
#
# Cluster 233 words: political, another, sexually, just, come, issue, needs, why, thanks, thing,
#
# Cluster 234 words: m, say, movement, feel, tried, happening, stand, don, watch, come,
#
# Cluster 235 words: claims, assaulted, rape, sexually, moment, new, people, reported, just, many,
#
# Cluster 236 words: hands, guy, women, abuse, harassing, say, wants, said, people, forced,
#
# Cluster 237 words: justice, era, victims, long, story, rights, important, world, new, today,
#
# Cluster 238 words: t, moment, because, happening, silence, assaulted, think, forced, people, years,
#
# Cluster 239 words: kind, thing, men, man, wants, harassing, assaulted, use, story, happening,
#
# Cluster 240 words: needs, speak, wake, listening, thing, woman, just, house, campaign, let,
#
# Cluster 241 words: tweets, please, sexually, sexually, rape, very, say, read, started, feminist,
#
# Cluster 242 words: child, victims, years, reported, breaking, old, protected, since, life, happening,
#
# Cluster 243 words: happening, t, n't, times, changing, campaign, something, rights, many, sign,
#
# Cluster 244 words: work, changing, thanks, sexually, just, only, tried, tell, story, speak,
#
# Cluster 245 words: write, before, read, 'm, posts, 've, twitter, why, many, great,
#
# Cluster 246 words: ago, happening, just, told, believe, only, lot, clinton, abuse, t,
#
# Cluster 247 words: power, men, thanks, making, n't, thing, sex, workplace, speak, assaulted,
#
# Cluster 248 words: any, man, accusations, sexually, victims, like, really, look, day, 've,
#
# Cluster 249 words: nyt, new, public, trump, actresses, white, workplace, day, sexually, culture,
#
# Cluster 250 words: forward, weeks, why, sexually, great, culture, read, very, say, power,
#
# Cluster 251 words: sexually, stop, just, resign, victims, donald, like, movement, n't, times,
#
# Cluster 252 words: school, sex, sexually, say, happening, stop, forced, very, because, just,
#
# Cluster 253 words: reasons, only, like, men, good, woman, harassing, making, anyone, wrong,
#
# Cluster 254 words: missed, political, women, n't, like, agree, making, apologize, oscars, read,
#
# Cluster 255 words: got, like, say, today, only, day, women, harassing, m, thought,
#
# Cluster 256 words: justice, social, women, sexually, reported, new, silence, times, like, story,
#
# Cluster 257 words: problem, assaulted, 's, like, campaign, needs, hollywood, because, victims, got,
#
# Cluster 258 words: male, victims, movement, needs, silence, day, way, s, another, times,
#
# Cluster 259 words: winning, trump, shares, times, t, think, really, another, nothing, good,
#
# Cluster 260 words: u, think, party, supporting, got, lie, daily, fucked, hopes, s,
#
# Cluster 261 words: day, fight, say, wants, many, inspired, thanks, only, always, vote,
#
# Cluster 262 words: rape, say, assaulted, only, people, just, before, accusations, stop, person,
#
# Cluster 263 words: asking, movement, work, just, latest, stop, only, era, supporting, making,
#
# Cluster 264 words: party, u, hands, know, harassing, just, years, end, wrong, tried,
#
# Cluster 265 words: society, sexually, way, movement, sexually, sexually, sex, times, long, equally,
#
# Cluster 266 words: public, sexually, why, supporting, like, making, needs, just, did, many,
#
# Cluster 267 words: care, really, abuse, sexually, just, say, assaulted, supporting, love, political,
#
# Cluster 268 words: wrong, people, s, accusations, said, man, someone, feel, believe, world,
#
# Cluster 269 words: pay, workplace, campaign, women, business, power, culture, job, years, does,
#
# Cluster 270 words: heard, speak, making, long, many, accusations, know, thanks, world, hear,
#
# Cluster 271 words: guy, think, asking, say, stop, rape, thing, said, men, way,
#
# Cluster 272 words: inspired, speak, love, power, words, sexually, rt, campaign, years, people,
#
# Cluster 273 words: everyone, needs, thanks, men, today, n't, sexually, hopes, said, women,
#
# Cluster 274 words: democrat, trump, clinton, women, supporting, rights, just, misconduct, assaulted, think,
#
# Cluster 275 words: pay, trump, sexually, just, victims, use, work, did, any, only,
#
# Cluster 276 words: very, women, thing, world, like, just, look, way, abuse, happening,
#
# Cluster 277 words: accusations, victims, woman, making, come, story, thing, someone, rights, moment,
#
# Cluster 278 words: child, help, assaulted, sexually, old, woman, stop, happening, someone, know,
#
# Cluster 279 words: friend, assaulted, 's, sexually, wants, shares, women, tried, girls, did,
#
# Cluster 280 words: since, day, times, thing, just, only, movement, work, before, wants,
#
# Cluster 281 words: brave, stand, tell, many, abuse, wants, just, posts, victims, needs,
#
# Cluster 282 words: maybe, political, women, s, hashtag, people, good, wants, making, got,
#
# Cluster 283 words: agree, needs, t, people, issue, rt, story, survivors, m, accusations,
#
# Cluster 284 words: senators, accusations, consent, s, only, think, n't, forced, good, any,
#
# Cluster 285 words: big, hollywood, lie, school, harassing, sexually, article, years, rights, work,
#
# Cluster 286 words: survivors, supporting, stand, believe, female, m, 's, 'm, feel, harassing,
#
# Cluster 287 words: today, many, read, speak, n't, thing, only, making, shares, new,
#
# Cluster 288 words: allow, abuse, men, speak, clinton, children, like, sexually, shameful, man,
#
# Cluster 289 words: kind, moment, new, movement, girls, s, sexually, only, wants, rights,
#
# Cluster 290 words: sorry, alone, thanks, experiences, stand, just, shares, brave, sure, true,
#
# Cluster 291 words: apologize, movement, speak, reported, needs, said, did, watch, think, because,
#
# Cluster 292 words: guess, posts, officers, help, speak, let, just, real, trump, started,
#
# Cluster 293 words: really, work, just, thing, men, t, talks, tried, come, woman,
#
# Cluster 294 words: new, s, harassing, thanks, woman, abuse, come, assaulted, thing, conversation,
#
# Cluster 295 words: sexually, lie, protected, 's, resign, day, abuse, why, s, needs,
#
# Cluster 296 words: sexually, hollywood, justice, left, say, asking, rape, assaulted, just, shares,
#
# Cluster 297 words: light, story, democrat, s, join, important, think, times, violence, includes,
#
# Cluster 298 words: reasons, let, little, good, today, best, joke, workplace, ca, happening,
#
# Cluster 299 words: strong, believe, speak, everyone, truth, let, needs, tell, t, thing,
#
# Cluster 300 words: lady, thanks, movement, like, needs, work, men, day, wants, rape,
#
# Cluster 301 words: sorry, apologize, say, experiences, women, really, wants, because, said, assaulted,
#
# Cluster 302 words: lives, talks, changing, because, news, n't, story, children, woman, years,
#
# Cluster 303 words: president, say, sexually, today, s, changing, n't, hopes, world, industry,
#
# Cluster 304 words: defends, women, men, behavior, rape, like, tried, protected, why, cases,
#
# Cluster 305 words: consent, culture, young, society, understand, means, age, school, piece, experiences,
#
# Cluster 306 words: anything, did, just, wants, movement, 've, tried, away, thing, times,
#
# Cluster 307 words: let, women, wake, hopes, rights, better, action, abuse, real, culture,
#
# Cluster 308 words: continue, speak, victims, many, thanks, workplace, making, because, please, silence,
#
# Cluster 309 words: something, just, wants, because, movement, rights, men, woman, thought, good,
#
# Cluster 310 words: black, woman, wear, 's, n't, s, rape, only, latest, making,
#
# Cluster 311 words: harvey, 's, say, know, harassing, nothing, thanks, oh, read, think,
#
# Cluster 312 words: actresses, party, women, daily, posts, read, rape, abuse, age, friend,
#
# Cluster 313 words: hollywood, women, moment, children, accusations, work, way, times, trump, speak,
#
# Cluster 314 words: female, speak, reported, new, world, why, many, forced, t, story,
#
# Cluster 315 words: 's, tried, tell, times, say, think, trump, sexually, every, changing,
#
# Cluster 316 words: social, 's, silence, reported, tweets, anything, franken, follow, act, donald,
#
# Cluster 317 words: since, times, women, rape, t, know, sexually, trump, got, before,
#
# Cluster 318 words: nothing, people, assaulted, men, know, thing, does, only, any, something,
#
# Cluster 319 words: investigation, sexually, democrat, female, movement, sex, women, s, say, n't,
#
# Cluster 320 words: young, woman, people, learning, school, sexually, needs, years, wants, child,
#
# Cluster 321 words: speech, bring, rights, any, s, use, liberalism, believe, stand, anyone,
#
# Cluster 322 words: reasons, good, claims, people, posts, hashtag, rights, supporting, tweets, wrong,
#
# Cluster 323 words: oprah, sexually, abuse, help, sure, leading, harvey, black, hopes, ignored,
#
# Cluster 324 words: behavior, women, workplace, accusations, liberalism, account, any, continue, act, reported,
#
# Cluster 325 words: culture, stop, needs, abuse, latest, reported, campaign, many, children, means,
#
# Cluster 326 words: face, women, accusations, harassing, victims, wants, oscars, changing, people, alleged,
#
# Cluster 327 words: media, watch, 's, movement, assaulted, sexually, rape, only, rights, needs,
#
# Cluster 328 words: era, stand, sexually, tried, n't, like, woman, changing, abuse, think,
#
# Cluster 329 words: help, needs, people, thanks, know, many, tell, just, only, times,
#
# Cluster 330 words: feel, n't, 'm, think, 've, man, sexually, talks, day, times,
#
# Cluster 331 words: courage, women, finally, many, power, say, believe, people, love, alone,
#
# Cluster 332 words: consent, sexually, culture, 's, t, someone, thing, think, piece, questions,
#
# Cluster 333 words: workplace, discuss, abuse, work, s, 's, started, men, new, many,
#
# Cluster 334 words: fear, women, lives, reported, assaulted, silence, making, let, rape, s,
#
# Cluster 335 words: age, men, 's, talks, female, lives, happening, shares, boys, asking,
#
# Cluster 336 words: experiences, women, person, 've, feel, every, work, s, like, think,
#
# Cluster 337 words: day, say, moment, making, n't, story, many, needs, think, people,
#
# Cluster 338 words: touched, asking, tried, women, girls, say, feel, sexually, comment, forced,
#
# Cluster 339 words: girls, woman, just, abuse, latest, stand, help, sexually, good, speak,
#
# Cluster 340 words: missed, n't, something, questions, just, cover, thing, think, happening, era,
#
# Cluster 341 words: times, making, person, tried, assaulted, many, started, come, way, people,
#
# Cluster 342 words: lot, men, n't, s, work, very, story, look, help, rights,
#
# Cluster 343 words: true, 's, movement, come, making, thing, people, words, any, supporting,
#
# Cluster 344 words: matters, only, movement, n't, women, sexually, life, like, feel, every,
#
# Cluster 345 words: ca, sexually, making, protected, why, sexually, oh, new, needs, any,
#
# Cluster 346 words: think, like, people, trump, t, tell, rape, abuse, someone, happening,
#
# Cluster 347 words: together, work, bring, making, amazing, join, creating, different, violence, march,
#
# Cluster 348 words: piece, thought, very, movement, today, like, era, men, check, t,
#
# Cluster 349 words: creating, changing, 's, sexually, why, victims, discuss, hopes, action, use,
#
# Cluster 350 words: oprah, hands, 's, president, ignored, party, people, nothing, stop, because,
#
# Cluster 351 words: watch, just, s, today, 'm, day, say, sexually, t, making,
# Cluster 352 words: step, public, hey, fucked, issue, n't, use, sexually, officers, bring,
#
# Cluster 353 words: free, talks, join, 's, movement, speak, help, use, woman, assaulted,
#
# Cluster 354 words: wondering, good, like, think, movement, before, started, because, m, today,
#
# Cluster 355 words: speech, president, message, night, new, great, during, black, look, said,
#
# Cluster 356 words: let, together, stop, just, say, bring, conversation, clear, world, 'm,
#
# Cluster 357 words: sure, n't, thing, many, truth, really, guy, check, use, way,
#
# Cluster 358 words: different, women, finally, gender, during, american, another, know, abuse, fight,
#
# Cluster 359 words: holding, hands, sexually, officers, people, story, tried, survivors, abuse, little,
#
# Cluster 360 words: great, day, times, look, love, men, thought, woman, job, help,
#
# Cluster 361 words: feel, making, just, times, years, needs, happening, sexually, sadly, changing,
#
# Cluster 362 words: workplace, women, issue, power, s, making, new, conversation, face, watch,
#
# Cluster 363 words: said, t, like, did, rape, think, men, stop, abuse, years,
#
# Cluster 364 words: family, children, know, rape, happening, tell, times, t, needs, speak,
#
# Cluster 365 words: sex, men, new, trump, say, because, changing, news, friend, many,
#
# Cluster 366 words: american, country, political, white, needs, agree, say, protected, continue, woman,
#
# Cluster 367 words: actually, thing, think, s, say, started, only, many, abuse, said,
#
# Cluster 368 words: come, story, just, new, thanks, thing, forced, children, changing, long,
#
# Cluster 369 words: shit, n't, men, know, man, s, real, old, movement, talks,
#
# Cluster 370 words: turns, black, 's, hollywood, sex, female, thing, feminist, abuse, many,
#
# Cluster 371 words: equally, fight, s, help, violence, sexually, long, supporting, important, needs,
#
# Cluster 372 words: away, n't, people, abuse, did, turns, way, friend, hands, something,
#
# Cluster 373 words: touched, man, 's, told, consent, tried, because, friend, sexually, very,
#
# Cluster 374 words: oprah, thanks, black, just, power, women, old, fucked, tell, know,
#
# Cluster 375 words: sexually, investigation, hits, survivors, cases, news, workplace, continue, different, step,
#
# Cluster 376 words: look, moment, women, new, needs, thing, t, times, power, only,
#
# Cluster 377 words: ca, 'm, people, wait, sexually, does, wants, does, did, rights,
#
# Cluster 378 words: needs, moment, just, thanks, people, woman, officers, children, person, alleged,
#
# Cluster 379 words: celebrities, 's, rape, backlash, film, n't, sexually, winning, abuse, say,
#
# Cluster 380 words: anyone, think, assaulted, please, harassing, why, rights, talks, woman, abuse,
#
# Cluster 381 words: daughter, t, thing, know, like, because, 's, 've, come, story,
#
# Cluster 382 words: cases, nyt, story, media, opinion, great, problem, world, assaulted, why,
#
# Cluster 383 words: inspired, amazing, many, oprah, shares, important, people, everyone, help, abuse,
#
# Cluster 384 words: weinstein, harassing, alleged, sexually, reported, sex, abuse, times, watch, read,
#
# Cluster 385 words: silence, 's, cover, sexually, kind, courage, brave, men, awards, winning,
#
# Cluster 386 words: social, face, harassing, sexually, use, person, news, alleged, 've, sexually,
#
# Cluster 387 words: american, finally, america, vote, think, reported, like, trump, issue, workplace,
#
# Cluster 388 words: night, did, watch, inspired, like, discuss, party, got, assaulted, life,
#
# Cluster 389 words: speech, best, big, listening, movement, love, political, needs, rights, m,
#
# Cluster 390 words: violence, stop, accusations, harassing, gender, male, use, started, work, story,
#
# Cluster 391 words: senators, sexually, president, say, trump, tell, political, assaulted, just, sexually,
#
# Cluster 392 words: wait, 'm, long, s, say, story, victims, thought, watch, thing,
#
# Cluster 393 words: story, daily, person, assaulted, men, tried, people, every, because, supporting,
#
# Cluster 394 words: young, men, man, know, sex, sexually, shameful, child, n't, experiences,
#
# Cluster 395 words: come, courage, story, n't, thanks, hopes, feel, experiences, just, speak,
#
# Cluster 396 words: alone, 'm, anyone, sexually, 's, woman, told, stand, always, man,
#
# Cluster 397 words: bad, feel, s, really, very, feminist, assaulted, story, 'm, man,
#
# Cluster 398 words: donald, trump, people, president, america, just, deserves, tried, senators, agree,
#
# Cluster 399 words: someone, sexually, please, tried, think, said, did, thing, 've, use,
#
# Cluster 400 words: years, movement, story, n't, moment, new, children, t, culture, every,
#
# Cluster 401 words: awards, times, years, n't, only, talks, important, industry, story, love,
#
# Cluster 402 words: lot, think, 've, thing, love, feel, n't, way, harassing, 'm,
#
# Cluster 403 words: holding, women, survivors, like, said, left, know, girls, tried, amazing,
#
# Cluster 404 words: because, women, only, thing, abuse, making, tell, rights, power, children,
#
# Cluster 405 words: points, changing, movement, sexually, harassing, article, shares, young, weinstein, boys,
#
# Cluster 406 words: account, men, culture, america, like, making, people, person, t, rape,
#
# Cluster 407 words: men, s, harassing, making, like, needs, way, know, shares, thanks,
#
# Cluster 408 words: new, moment, cause, years, women, golden, book, children, guess, winning,
#
# Cluster 409 words: don, wants, like, men, feel, sexually, happening, movement, abuse, stop,
#
# Cluster 410 words: different, sexually, movement, 's, know, something, experiences, hopes, means, life,
#
# Cluster 411 words: disgusting, just, democrat, kids, words, vote, supporting, points, march, men,
#
# Cluster 412 words: moore, donald, political, weinstein, does, anything, stay, clinton, rights, nothing,
#
# Cluster 413 words: equally, stay, march, movement, important, workplace, includes, stand, society, campaign,
#
# Cluster 414 words: silent, why, harassing, voices, men, any, just, courage, blaming, nothing,
#
# Cluster 415 words: many, men, like, abuse, n't, harassing, why, supporting, way, sadly,
#
# Cluster 416 words: sexually, harassing, movement, help, tell, talks, supporting, stop, times, hollywood,
#
# Cluster 417 words: inspired, abuse, look, sexually, 's, stand, woman, day, silence, hollywood,
#
# Cluster 418 words: democrat, nyt, amazing, sexually, harassing, vote, m, black, great, every,
#
# Cluster 419 words: continue, action, years, let, why, men, changing, cases, hollywood, stand,
#
# Cluster 420 words: nothing, said, movement, know, because, victims, people, feel, times, great,
#
# Cluster 421 words: sexually, face, new, donald, accusations, another, forced, say, responsible, s,
#
# Cluster 422 words: issue, s, sexually, victims, just, like, silence, campaign, speak, look,
#
# Cluster 423 words: every, times, men, assaulted, believe, abuse, feel, wants, n't, rape,
#
# Cluster 424 words: before, way, movement, happening, tell, why, sexually, stop, know, making,

# %%
from __future__ import print_function

#sort cluster centers by proximity to centroid
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-5] 

cluster = []
vocab = []

for i in range(num_clusters):
    for ind in order_centroids[i, :10]: #replace 6 with n words per cluster
        cluster.append(i)
        vocab.append(vocab_frame.loc[terms[ind].split(' ')].values.tolist()[0][0])

print(len(vocab))
print(len(cluster))
# Out:
# 4250
# 4250

# %%
# vocab_list = pd.DataFrame({
#     'cluster': cluster,
#     'word': vocab
# })

# # print(vocab_list)

# %%
# vocab_list.to_csv('vocab_list.csv', index=False)

# %%
# # cluster = data.loc[(data.cluster == 0)]
# # cluster.shape

# for num in range(0,475):
# #     print(num)
# #     print('cluster_' + str(num))
#     cluster = data.loc[(data.cluster == num)]
#     cluster.to_csv('cluster_' + str(num))
# #     print(num.shape)

# %%
cluster_test = data.loc[data.cluster.isin([22]),]
filtered_test = cluster_test.nlargest(20, 'engagement')

for index, row in filtered_test.iterrows():
    print(row['original_text'])
    print()
    print(row['engagement'])
    print()
    print('***')
# Out:
# #MeToo
# #FakeCases
# My  Friends Story: My Wife Filed A False Litigation Against Me; I Fought The Case And Won Ithttp://fb.me/GWJ8i25K
#
# 335
#
# ***
# #MeToo movement looms over jury selection in Bill Cosby case http://blbrd.cm/cVQlfe pic.twitter.com/zVts3w97ce
#
# 269
#
# ***
# “In the case of the girls, we should exact a price at some other opportunity, in the dark, without witnesses and cameras”
#
# Ben Caspit - Israeli Journalist
#
# commenting on #AhadTamimi
# #Metoo
# #HarveyWeinstein #Justice #Palestinehttps://twitter.com/georgegalloway/status/944955896026877953 …
#
# 242
#
# ***
# Nice. My 1st academic publication! A chapter I wrote for this volume, using @clearlinesuk as a case study for engaged art to #endVAWG - emotional & unpaid labour & the constraints upon #activism #MeToo #TimesUp #phdlifepic.twitter.com/yyhTzGUclj
#
# 170
#
# ***
# So much for #METOO and #TIMESUP: U.S. judge “goes to bat” for FGM in landmark case, reports David Menzies https://www.therebel.media/so_much_for_metoo_and_timesup_u_s_judge_goes_to_bat_for_fgm_in_landmark_case … | #tcot #newspic.twitter.com/xjlZe9jpfZ
#
# 164
#
# ***
# Liar! Liar! Liar! The Curious Case Of Rabid Fandom #metoo https://melissaexplainsitall.wordpress.com/2017/12/19/liar-liar-liar/ …
#
# 155
#
# ***
# At NRO: 'What the Bishop Bell case reveals about our #MeToo moment'. http://www.nationalreview.com/article/454794/bishop-bell-case-what-it-reveals-about-metoo-moment …
#
# 125
#
# ***
# #meetoo what about male victim who are suffering from False cases by greedy womens ? @sifgujarat @vaastavngo @sif_india @siff4india @Milkyway1955Z @purush_aayog @VDaivesh @HridayaNFH @AnupamDLive @wisehussein @PMOIndia @CMOGuj @MinistryWCD @purushaayog @rekhara17806375 #MeToo pic.twitter.com/Gy2r6m2lSq
#
# 114
#
# ***
# Third rape case collapses after defence unearths key evidence http://dailym.ai/2FEQrjX  via @MailOnline #FakeCases #WalkForMen #scrap498a #ScrapGenderBiasedLaws #MeToo #TIMESUP #FakeEmpowerment #FakeFeminism
#
# 114
#
# ***
# “Was it because Mr. Yamaguchi had a close relationship w/Prime Minister Abe that the case was brought all the way up to, and rejected by, the division head himself?” #MeToo #詩織さん #ICYMIhttps://www.japantimes.co.jp/news/2017/11/22/national/crime-legal/lawmakers-take-dropped-rape-charge-leveled-former-high-profile-journalist/#.WhfSmfNrD4U.twitter …
#
# 81
#
# ***
# UPLC has filed a case against IDOC on behalf of Strawberry Hampton, a transwoman STILL being held in Menard men's prison. #FreeStrawberry #TransRightsAreHumanRights #MeToo  #TimesUp  @BLMChi @BSAllianceChi @MomsUnitedChi @LoveProtectOrgpic.twitter.com/cSyFUhuQyx
#
# 80
#
# ***
# 'LORENA' to re-examine Bobbitt case for #MeToo era... https://drudge.tw/2q8eeSw
#
# 79
#
# ***
# Interesting how you deviated to cases from years ago. Even though the comment 'ruining these men's career' obviously refers to all the recent cases pertaining to the #MeToo movement
#
# 77
#
# ***
# I've pinned this up on the fridge, in case my wife forgets any of it. #Feminist #TimesUp #MeToo pic.twitter.com/ZsRewdHpHO
#
# 71
#
# ***
# UPLC has filed a case against IDOC on behalf of Strawberry Hampton, a transwoman STILL being held in Menard men's prison. #FreeStrawberry #TransRightsAreHumanRights #MeToo #TimesUp @BLMChi @BSAllianceChi @MomsUnitedChi @LoveProtectOrgpic.twitter.com/by9rxNxKZX
#
# 70
#
# ***
# "I wrote a comprehensive timeline of the #RyanSeacrest case...shows how transformative it can be when someone gives their name & voice to their story. The case against Seacrest was closed, literally, until Suzie Hardy came forward." #MeToo @jessicagoldshttps://thinkprogress.org/ryan-seacrest-allegations-oscars-e915f23b2576/ …
#
# 67
#
# ***
# Some general thoughts I wrote on #MeToo for @CounselMagazine, in case you’re interested.https://twitter.com/counselmagazine/status/943821636456865793 …
#
# 67
#
# ***
# #IamThatWoman who filed False #Dowry cases which led 2 #HusbandSuicide !!
#
# #MeToo
# @NITIAayog
# @OfficeOfRSP
# @Devinder_Sharma
# @ANI
# @TimesNowhttps://twitter.com/rajendrk/status/925396469917429760 …
#
# 64
#
# ***
# In case some of you guys came in late... https://johnpavlovitz.com/2017/10/16/men-side-metoo/ … #MeToo
#
# 64
#
# ***
# #CrimeByWomen
# #MeToo
# @dna
# Mamta Kulkarni's 3 Andheri flats to be attached in 2016 drug bust case http://toi.in/tgjY7Z/a24gj  via @timesofindia
#
# 60
#
# ***

# %%
# for index, row in data.iterrows():
# if row['cluster'] == 409:
#     print(row['text'])
#     print()
#     print(row['hashtags'])
#     print()
#     print('***')

# %% [markdown]
# ### Cluster Group 1 = Poltics

# %%
cluster_group_1 = data.loc[data.cluster.isin([90,159,274,303,366,398]),]
print(cluster_group_1.shape)
# Out:
# (13623, 15)

# %%
filtered_group_1 = cluster_group_1.nlargest(1000, 'engagement')
filtered_group_1.shape
# Out:
# (1000, 15)

# %%
politics = pd.DataFrame(data = filtered_group_1, columns = ['id','original_text','user','url','timestamp','likes','retweets','replies','engagement','cluster'])
politics.head()
# Out:
#                         id                                      original_text  \
# 196938  938642541616009216  Poll: 70% of Americans says Congress should in...
# 38741   972678963326783488  If #PA18 voters need another reason to vote fo...
# 37476   958549075539955712  The Democrats pulled out a Kennedy speaking Sp...
# 39278   958514984497147904  Democrats will be wearing all black at tonight...
# 156862  940415771376738304  56 U.S. House Democratic women seek probe of T...
#
#                    user                                         url  \
# 196938           funder           /funder/status/938642541616009216
# 38741   joncoopertweets  /joncoopertweets/status/972678963326783488
# 37476           Yamiche          /Yamiche/status/958549075539955712
# 39278      PrisonPlanet     /PrisonPlanet/status/958514984497147904
# 156862  AynRandPaulRyan  /AynRandPaulRyan/status/940415771376738304
#
#                  timestamp  likes  retweets  replies  engagement  cluster
# 196938 2017-12-07 05:33:15   7641     10455      237       28788      366
# 38741  2018-03-11 03:41:51   5625      3653      106       13037      159
# 37476  2018-01-31 03:54:43   6467      1572      145        9756      274
# 39278  2018-01-31 01:39:15   4816      1974      191        8955      274
# 156862 2017-12-12 02:59:26   4288      2123      126        8660      274

# %%
path = 'politics.json'
politics.to_json(path_or_buf= path ,orient='records')

# %% [markdown]
# ### Cluster Group 2 = Workplace

# %%
cluster_group_2 = data.loc[data.cluster.isin([244, 333, 362]),]
print(cluster_group_2.shape)
# Out:
# (7392, 15)

# %%
filtered_group_2 = cluster_group_2.nlargest(1000, 'engagement')
filtered_group_2.shape
# Out:
# (1000, 15)

# %%
workplace = pd.DataFrame(data = filtered_group_2, columns = ['id','original_text','user','url','timestamp','likes','retweets','replies','engagement','cluster'])
workplace.head()
# Out:
#                         id                                      original_text  \
# 338528  950086665439272960  1 in 3 women have been sexually harassed in th...
# 273001  952773184931139584  The #metoo conversation is getting murky, but ...
# 164204  963836829572071424  A man that works in my building at work approa...
# 56509   966550741396619264  A new survey finds 81 percent of women in Amer...
# 110998  941834629073453056  .@LisaBloom is also hurting women in the workp...
#
#                    user                                         url  \
# 338528    Alyssa_Milano    /Alyssa_Milano/status/950086665439272962
# 273001       laurenduca       /laurenduca/status/952773184931139584
# 164204  Patrici15767099  /Patrici15767099/status/963836829572071424
# 56509               NPR              /NPR/status/966550741396619265
# 110998      bacon_texas      /bacon_texas/status/941834629073453056
#
#                  timestamp  likes  retweets  replies  engagement  cluster
# 338528 2018-01-07 19:28:07   6841      3085      293       13304      333
# 273001 2018-01-15 05:23:23   2747       262       23        3294      333
# 164204 2018-02-14 18:06:22   1461       346      118        2271      244
# 56509  2018-02-22 05:50:29    618       319       65        1321      333
# 110998 2017-12-16 00:57:28    440       283       40        1046      362

# %%
path = 'workplace.json'
workplace.to_json(path_or_buf= path ,orient='records')

# %% [markdown]
# ### Cluster Group 3 = Toxic Language

# %%
cluster_group_3 = data.loc[data.cluster.isin([104, 107, 192, 22]),]
print(cluster_group_3.shape)
# Out:
# (10011, 15)

# %%
filtered_group_3 = cluster_group_3.nlargest(1000, 'engagement')
filtered_group_3.shape
# Out:
# (1000, 15)

# %%
toxic = pd.DataFrame(data = filtered_group_3, columns = ['id','original_text','user','url','timestamp','likes','retweets','replies','engagement','cluster'])
toxic.head()
# Out:
#                         id                                      original_text  \
# 1247    980492707809312768  You are implying that women with certain jobs ...
# 219306  938441664439369728  Don't fucking making fun of Taylor Swift & min...
# 87928   933468165220089856  THIS IS SO INFURIATING. THIS IS SO DISGUSTING....
# 67643   982713584818978816  Among the many gross notions that are embedded...
# 71170   982661301842403328  Tony Robbins has made millions of dollars putt...
#
#                  user                                       url  \
# 1247    StormyDaniels  /StormyDaniels/status/980492707809312768
# 219306      jillboard      /jillboard/status/938441664439369728
# 87928   Alyssa_Milano  /Alyssa_Milano/status/933468165220089861
# 67643   emilynussbaum  /emilynussbaum/status/982713584818978816
# 71170         eorlins        /eorlins/status/982661301842403328
#
#                  timestamp  likes  retweets  replies  engagement  cluster
# 1247   2018-04-01 17:10:52  57804      9000     1127       76931      104
# 219306 2017-12-06 16:15:02  29121      7812      238       44983      107
# 87928  2017-11-22 22:52:08   4090      2807      341       10045      104
# 67643  2018-04-07 20:15:51   4972       993       92        7050      104
# 71170  2018-04-07 16:48:05   3931      1290      203        6714      104

# %%
path = 'toxic.json'
toxic.to_json(path_or_buf= path ,orient='records')

# %% [markdown]
# ### Cluster Group 4 = Support

# %%
cluster_group_4 = data.loc[data.cluster.isin([197,230,286,371]),]
print(cluster_group_3.shape)
# Out:
# (11679, 15)

# %%
filtered_group_4 = cluster_group_4.nlargest(1000, 'engagement')
filtered_group_4.shape
# Out:
# (1000, 15)

# %%
support = pd.DataFrame(data = filtered_group_4, columns = ['id','original_text','user','url','timestamp','likes','retweets','replies','engagement','cluster'])
support.head()
# Out:
#                         id                                      original_text  \
# 338519  950086987863662592  Michelle Williams is bringing founder of the #...
# 50286   920313515705028608  Meet @TaranaBurke, the Activist Who Started #M...
# 12354   948733639512281088  Today’s #WCW is @TaranaBurke, creator of the #...
# 182254  956531745737895936  Woke up with the brave Olympic gymnast and all...
# 154551  954478137865367552  Today, I stood up to the enemy that sexually a...
#
#                  user                                       url  \
# 338519        Variety        /Variety/status/950086987863662592
# 50286    democracynow   /democracynow/status/920313515705028608
# 12354   itsgabrielleu  /itsgabrielleu/status/948733639512281094
# 182254    TaranaBurke    /TaranaBurke/status/956531745737895937
# 154551       hmorrow6       /hmorrow6/status/954478137865367557
#
#                  timestamp  likes  retweets  replies  engagement  cluster
# 338519 2018-01-07 19:29:24   4632      1148       73        7001      230
# 50286  2017-10-17 15:40:15   2662      1443       32        5580      197
# 12354  2018-01-04 01:51:40   2759      1107       23        4996      230
# 182254 2018-01-25 14:18:34   3479       601       17        4698      286
# 154551 2018-01-19 22:18:16   3434       366       76        4242      286

# %%
path = 'support.json'
support.to_json(path_or_buf= path ,orient='records')

# %% [markdown]
# ### Cluster Group 5 = Uplifting

# %%
cluster_group_5 = data.loc[data.cluster.isin([163, 169, 217, 272, 281, 331, 347, 356, 383]),]
print(cluster_group_5.shape)
# Out:
# (26130, 15)

# %%
filtered_group_5 = cluster_group_5.nlargest(1000, 'engagement')
filtered_group_5.shape
# Out:
# (1000, 15)

# %%
uplifting = pd.DataFrame(data = filtered_group_5, columns = ['id','original_text','user','url','timestamp','likes','retweets','replies','engagement','cluster'])
uplifting.head()
# Out:
#                         id                                      original_text  \
# 20282   982389487836778496  Life coach Tony Robbins says women are using #...
# 40748   922826342890131456  One tweet has brought together 1.7 million voi...
# 106993  942029266543435776  Shout out to all the strong and beautiful wome...
# 20413   946733185488113664  #MeToo Let's change this - Women rule the worl...
# 37547   958548768537923584  “You bravely say, #metoo. You steadfastly say,...
#
#                   user                                        url  \
# 20282      nowthisnews     /nowthisnews/status/982389487836778496
# 40748    Alyssa_Milano   /Alyssa_Milano/status/922826342890131456
# 106993  LaurenJauregui  /LaurenJauregui/status/942029266543435778
# 20413         vonstolk        /vonstolk/status/946733185488113665
# 37547    RepJoeKennedy   /RepJoeKennedy/status/958548768537923584
#
#                  timestamp  likes  retweets  replies  engagement  cluster
# 20282  2018-04-06 22:48:00  27988     12831     5701       59351      281
# 40748  2017-10-24 14:05:20  27905      5001      975       38882      347
# 106993 2017-12-16 13:50:53  18960      5837      439       31073      169
# 20413  2017-12-29 13:22:35  15997      3432        2       22863      356
# 37547  2018-01-31 03:53:30   9883      2836      430       15985      281

# %%
path = 'uplifting.json'
uplifting.to_json(path_or_buf= path ,orient='records')

# %% [markdown]
# ### Cluster Group 6 = Oprah

# %%
cluster_group_6 = data.loc[data.cluster.isin([323, 350, 374]),]
print(cluster_group_6.shape)
# Out:
# (2841, 15)

# %%
filtered_group_6 = cluster_group_5.nlargest(1000, 'engagement')
filtered_group_6.shape
# Out:
# (1000, 15)

# %%
oprah = pd.DataFrame(data = filtered_group_6, columns = ['id','original_text','user','url','timestamp','likes','retweets','replies','engagement','cluster'])
oprah.head()
# Out:
#                         id                                      original_text  \
# 296719  950754335578783744  How can Oprah be a credible voice for abused w...
# 296074  950768408223678464  Oprah:\n"We will reach a time when no woman ha...
# 300980  950608721167765504  Flashback: British Actress Says Weinstein Used...
# 322094  950253288162652160  Oprah Winfrey celebrates Time’s Up & #metoo as...
# 295774  950774413804298240  #MyTake on Oprah and the wondertards of Hollyw...
#
#                  user                                       url  \
# 296719   PrisonPlanet   /PrisonPlanet/status/950754335578783744
# 296074   allidoisowen   /allidoisowen/status/950768408223678464
# 300980   chuckwoolery   /chuckwoolery/status/950608721167765510
# 322094       HuffPost       /HuffPost/status/950253288162652160
# 295774  MarcusBrutus_  /MarcusBrutus_/status/950774413804298240
#
#                  timestamp  likes  retweets  replies  engagement  cluster
# 296719 2018-01-09 15:41:12   3834      1808      364        7814      374
# 296074 2018-01-09 16:37:07   3360      1192       99        5843      374
# 300980 2018-01-09 06:02:35   1979      1537      168        5221      323
# 322094 2018-01-08 06:30:13   2377       710       70        3867      374
# 295774 2018-01-09 17:00:59   1143       735      136        2749      374

# %%
path = 'oprah.json'
oprah.to_json(path_or_buf= path ,orient='records')
